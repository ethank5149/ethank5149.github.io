# %% [markdown]
# # Outline $\circ$ Branches $\circ$ Concepts $\circ$ Topics $\circ$ Physics (x)

# %% [markdown]
# __Physics__ – natural science that involves the study of matter and its motion through spacetime, along with related concepts such as energy and force. More broadly, it is the general analysis of nature, conducted in order to understand how the universe behaves. a scientific discipline that seeks to construct and experimentally test theories of the physical universe. The solution of tractable problems in nature.
#
# __Universe__ - everything that physically exists: the entirety of space and time, all forms of matter, energy and momentum, and the physical laws and constants that govern them. However, the term 'universe' may also be used in slightly different contextual senses, denoting concepts such as the cosmos or the philosophical world.

# %% [markdown]
# #### ["You just gotta tighten up the bolts a little bit" - Sips](https://youtu.be/9653yNP0pYk?t=6740)

# %% [markdown]
# #### Original HyperPhysics Network Diagrams

# %%
from IPython.display import Image, SVG

# %%
# Source: 'http://hyperphysics.phy-astr.gsu.edu/hbase/'
original_graph_hyperphysics = Image('./Photos/HyperPhysics/Hyperphysics.gif')
original_graph_electromagnetism = Image('./Photos/HyperPhysics/Electromagnetism/Electromagnetism.gif')
original_graph_optics = Image('./Photos/HyperPhysics/Optics/Optics.gif')
original_graph_mechanics = Image('./Photos/HyperPhysics/Mechanics/Mechanics.gif')
original_graph_acoustics = Image('./Photos/HyperPhysics/Acoustics/Acoustics.gif')
original_graph_thermodynamics = Image('./Photos/HyperPhysics/Thermodynamics/Thermodynamics.gif')
original_graph_relativity = Image('./Photos/HyperPhysics/Relativity/Relativity.gif')
original_graph_condensed_matter = Image('./Photos/HyperPhysics/CondensedMatter/CondensedMatter.gif')
original_graph_astrophysics = Image('./Photos/HyperPhysics/Astrophysics/Astrophysics.png')
original_graph_nuclear = Image('./Photos/HyperPhysics/Nuclear/Nuclear.png')
original_graph_quantum = Image('./Photos/HyperPhysics/Quantum/QuantumPhysics.gif')

# %% [markdown]
# #### Recreations Using ```mermaid```

# %%
mermaid_graph_hyperphysics = Image('./Photos/Mermaid/Physics/HyperPhysics.png')
mermaid_graph_electromagnetism = Image('./Photos/Mermaid/Physics/Electromagnetism.png')
mermaid_graph_optics = Image('./Photos/Mermaid/Physics/Optics.png')
mermaid_graph_mechanics = Image('./Photos/Mermaid/Physics/Mechanics.png')
mermaid_graph_acoustics = Image('./Photos/Mermaid/Physics/Acoustics.png')
mermaid_graph_thermodynamics = Image('./Photos/Mermaid/Physics/Thermodynamics.png')
mermaid_graph_relativity = Image('./Photos/Mermaid/Physics/Relativity.png')
mermaid_graph_condensed_matter = Image('./Photos/Mermaid/Physics/CondensedMatter.png')
mermaid_graph_astrophysics = Image('./Photos/Mermaid/Physics/Astrophysics.png')
mermaid_graph_nuclear = Image('./Photos/Mermaid/Physics/Nuclear.png')
mermaid_graph_quantum = Image('./Photos/Mermaid/Physics/QuantumPhysics.png')

# %% [markdown]
# ##### Hard-Coding Labels

# %%
# A
(
    aberration_of_starlight,
    absorption,
    acoustics,
    ac_circuits,
    adiabatic,
    advance_of_perihelion_of_mercury,
    air_columns,
    alpha,
    amperes_law,
    aperture,
    applications,
    astrophysics,
    atmospheric_phenomena,
    atomic_properties,
    auditorium_acoustics,
    ) = (
        'Aberration \nof \nStarlight',
        'Absorption',
        'Acoustics',
        'AC \nCircuits',
        'Adiabatic',
        'Advance of \nPerihelion \nof Mercury',
        'Air Columns',
        'Alpha',
        "Ampere's \nLaw",
        'Aperture',
        'Applications',
        'Astrophysics',
        'Atmospheric \nPhenomena',
        'Atomic \nProperties',
        'Auditorium \nAcoustics',
        )
# B
(
    band_theory_of_solids,
    beta,
    beats,
    bioelectrity,
    biot_savart_law,
    blackbody_radiation,
    black_hole,
    black_holes,
    bl_lacertae_objects,
    bohr_theory,
    boltzmann_distribution,
    ) = (
        'Band Theory \nof Solids',
        'Beta',
        'Beats',
        'Bioelectrity',
        'Biot-Savart \nLaw',
        'Blackbody \nRadiation',
        'Black \nHole',
        'Black \nHoles',
        'BL \nLacertae \nObjects',
        'Bohr \nTheory',
        'Boltzmann \nDistribution',
        )
# C
(
    contraction,
    color,
    color_vision,
    circular_motion,
    circuit_elements,
    condensed_matter,
    capacitor,
    coulombs_law,
    current_law,
    conservation_laws,
    conservation_of_energy,
    constant_volume,
    conservation_of_momentum,
    conservation_of_angular_momentum,
    compton_scattering,
    condensed_matter,
    conduction,
    convection,
    crystal_lattice,
    celestial_measurement,
    cosmology,
    ) = (
        'Capacitor',
        'Celestial \nMeasurement',
        'Circuit \nElements',
        'Circular \nMotion',
        'Color',
        'Color \nVision',
        'Compton \nScattering',
        'Condensed \nMatter',
        'Conduction',
        'Conservation \nLaws',
        'Conservation of \nAngular \nMomentum',
        'Conservation \nof \nEnergy',
        'Conservation \nof \nMomentum',
        'Constant \nVolume',
        'Contraction',
        'Convection',
        'Cosmology',
        "Coulomb's \nLaw",
        'Crystal \nLattice',
        'Current \nLaw',
        )
# D
(
    decay_paths,   
    density_parameter, 
    distance_measurement,
    dc_circuits,
    diamagnetism,
    dielectric_media,
    double_slit,
    diffraction,
    decibels,
    doppler_shift,
    dba,
    doppler_effect,
    ) = (
        'Decay \nPaths',   
        'Density \nParameter', 
        'Distance \nMeasurement',
        'DC \nCircuits',
        'Diamagnetism',
        'Dielectric \nMedia',
        'Double \nSlit',
        'Diffraction',
        'Decibels',
        'Doppler \nShift',
        'dBA',
        'Doppler \nEffect',
        )

# E
(
    emc2,
    experiments_of_general_relativity,
    experiments_of_special_relativity,
    einstein_velocity_addition,
    equal_tempered,
    equilibrium,
    electric_circuits,
    electric_charge,
    electric_current,
    electric_field,
    electric_power,
    electromagnetism,
    electronics,
    em_waves,
    emf,
    electrical_properties,
    expanding_universe,
    electron_density,
    entropy,
    enthalpy,
    equipartition_of_energy,
    ) = (
        'E=mc^2',
        'Experiments of \nGeneral Relativity',
        'Experiments of \nSpecial Relativity',
        'Einstein \nVelocity \nAddition',
        'Equal \nTempered',
        'Equilibrium',
        'Electric \nCircuits',
        'Electric \nCharge',
        'Electric \nCurrent',
        'Electric \nField',
        'Electric \nPower',
        'Electromagnetism',
        'Electronics',
        'EM \nWaves',
        'EMF',
        'Electrical \nProperties',
        'Expanding \nUniverse',
        'Electron \nDensity',
        'Entropy',
        'Enthalpy',
        'Equipartition \nof Energy',
        )

# F
(
    first_law_of_thermodynamics,
    fermi_energy,
    ferromagnetism,
    failures_of_classical_physics,
    fast_breeder,
    fusion_reactors,
    fluid_mechanics,
    fabry_perot_interferometer,
    fraunhofer,
    fourier_optics,
    fiber_optics,
    fresnel,
    faradays_law,
    forces,
    ) = (
        'First Law of \nThermodynamics',
        'Fermi \nEnergy',
        'Ferromagnetism',
        'Failures of \nClassical Physics',
        'Fast \nBreeder',
        'Fusion \nReactors',
        'Fluid \nMechanics',
        'Fabry-Perot \nInterferometer',
        'Fraunhofer',
        'Fourier \nOptics',
        'Fiber \nOptics',
        'Fresnel',
        "Faraday's \nLaw",
        'Forces',
        )
# G
(
    gravity,
    gamma,
    galilean_transformation, 
    gravitational_contraction,
    gravitational_time_dilation,
    gravitational_waves, 
    grating,
    gausss_law
    ) = (
        'Gravity',
        'Gamma',
        'Galilean \nTransformation',
        'Gravitational \nContraction',
        'Gravitational \nTime \nDilation',
        'Gravitational \nWaves',
        'Grating',
        "Gauss's \nLaw",
        )
# H
hearing,    hydrogen_energies, hydrogen_spectrum = 'Hearing',    'Hydrogen \nEnergies', 'Hydrogen \nSpectrum', 
heat,       heat_engines,      heat_transfer     = 'Heat',       'Heat \nEngines',      'Heat \nTransfer', 
holography, hyperphysics,      household_wiring  = 'Holography', 'HyperPhysics',      'Household \nWiring',
half_life,  h_he_abundance                       = 'Half \nLife',  'H-He \nAbundance',
# I
inductor,             inverse_square_law,          interference                =   'Inductor',       'Inverse \nSquare \nLaw',   'Interference',
isotopes,             ideas_of_special_relativity, ideas_of_general_relativity =     'Isotopes',  'Ideas of \nSpecial \nRelativity',          'Ideas of \nGeneral \nRelativity', 
internal_energy,      isothermal,                  ideal_gas_law               = 'Internal \nEnergy',    'Isothermal',                   'Ideal \nGas \nLaw', 
interference_filters, index_of_refraction,                                     =          'Interference \nFilters',  'Index of \nRefraction',
# K
kinetic_theory,         = 'Kinetic \nTheory',  
# L
lorentz_transformation, lattice_vibrations, lorentz_force_law = 'Lorentz \nTransformation', 'Lattice \nVibrations',"Lorentz' \nForce \nLaw"
light_water_reactions,  loudness,           lasers            =   'Light \nWater \nReactions', 'Loudness',     'Lasers' 
lenses,                 light_intensity,    light_propagation = 'Lenses',                'Light \nIntensity',            'Light \nPropagation'
length_contraction                                            =       'Length \nContraction',                   
# M
michelson_morley_experiment, musical_instruments, musical_scales           =   'Michelson-Morley \nExperiment',    'Musical \nInstruments',  'Musical \nScales',
muon_experiment,             main_sequence,       milky_way_galaxy         = 'Muon \nExperiment', 'Main \nSequence',           'Milky \nWay \nGalaxy',            
mechanics,                   metals,              magnetic_properties      =  'Mechanics','Metals',                  'Magnetic \nProperties', 
mirrors,                     mirror_instruments,  michelson_interferometer = 'Mirrors',               'Mirror \nInstruments',         'Michelson \nInterferometer'
magnetic_field,              maxwells_equations,  measurement              = 'Magnetic \nField',   "Maxwell's \nEquations", 'Measurement'
mass                                                                       =                      'Mass',               
# N
nuclear,                nuclear_particles,   nuclear_structure      = 'Nuclear',            'Nuclear \nParticles',   'Nuclear \nStructure', 
nuclear_reactions,      nuclear_energy,      nuclear_medicine       = 'Nuclear \nReactions',  'Nuclear \nEnergy',      'Nuclear \nMedicine',
nuclear_notation,       nuclear_forces,      nuclear_binding_energy = 'Nuclear \nNotation',   'Nuclear \nForces',      'Nuclear \nBinding Energy', 
nuclear_fission,        nuclear_fusion,      nuclear_size           = 'Nuclear \nFission',    'Nuclear \nFusion',      'Nuclear \nSize',
nuclear_spectra,        nuclear_scale_model, nuclear_units          = 'Nuclear \nSpectra',    'Nuclear \nScale \nModel', 'Nuclear \nUnits',
nova,                   nuclear_weapons,     neutron_star           = 'Nova',  'Nuclear \nWeapons',    'Neutron Star',
nuclear_binding_energy, newtons_laws                                = 'Nuclear \nBinding \nEnergy',"Newton's \nLaws"
# O
orbits,   other_galaxies,     optics = 'Orbits',      'Other \nGalaxies',     'Optics',
ohms_law, optical_instruments        = "Ohm's \nLaw", 'Optical \nInstruments' 
# P
pre_nova,          post_nova,            pulsar                   =  'Pre-Nova', 'Post-Nova',               'Pulsar',                       
planck_hypothesis, photoelectric_effect, particles                = 'Planck \nHypothesis',       'Photoelectric \nEffect',  'Particles', 
particle_physics,  piezoelectric_effect, paramagnetism            = 'Particle \nPhysics', 'Piezoelectric \nEffect',  'Paramagnetism',           
periodic_table,    pv_diagrams,          phase_changes            =  'Periodic \nTable',  'PV \nDiagrams',                  'Phase \nChanges',
photometry,        prisms,               polarization             =   'Photometry',            'Prisms',     'Polarization'
periodic_motion,   phons,                pitch                    = 'Periodic \nMotion',   'Phons',                'Pitch', 
pythagorean,       physical_units,       principle_of_equivalence = 'Pythagorean',   'Physical \nUnits',     'Principle \nof \nEquivalence', 
# Q
quantum_properties, quantum, quantum_numbers = 'Quantum \nProperties',        'Quantum',               'Quantum \nNumbers',
quantum_statistics, quasars                  = 'Quantum \nStatistics', 'Quasars', 
# R
red_giant_post_nova, radiation,           relative_humidity                  = 'Red Giant \n(Post-Nova)', 'Radiation',          'Relative \nHumidity',                 
red_giant,           red_giant_pre_nova,  red_supergiant                     = 'Red \nGiant',               'Red Giant \n(Pre-Nova)',      'Red \nSupergiant', 
radiation_risk,      radiation_curves,    radioactivity                      =  'Radiation \nRisk','Radiation \nCurves', 'Radioactivity', 
radioactive_dating,  radiation_detection, rutherford_scattering              = 'Radioactive \nDating', 'Radiation \nDetection', 'Rutherford \nScattering', 
resistor,            refraction,          reflection                         = 'Resistor','Refraction',            'Reflection',                  
rotation,            resonance,           relativistic_mechanical_quantities =  'Rotation',  'Resonance', 'Relativistic \nMechanical \nQuantities'
relativity,          reverberation,       relativistic_mass                  = 'Relativity',       'Reverberation', 'Relativistic \nMass',       
# S
(
    snells_law,
    single_slit,
    scattering,
    sound_propagation,
    sound_reproduction,
    standing_waves,
    strings,
    solar_system,
    seyfert_galaxies,
    sound_measurement,
    supernova,
    stars,
    semiconductor_properties,
    schrodinger_equation,
    solid_mechanics,
    superconductivity,
    solid_state_electronics,
    specific_heat,
    second_law_of_thermodynamics,
    system_work
    ) = (
        "Snell's \nLaw",
        'Single \nSlit',
        'Scattering',
        'Sound \nPropagation',
        'Sound \nReproduction',
        'Standing Waves',
        'Strings',
        'Solar \nSystem',
        'Seyfert Galaxies',
        'Sound \nMeasurement',
        'Supernova',
        'Stars',
        'Semiconductor \nProperties',
        'Schrodinger \nEquation',
        'Solid \nMechanics',
        'Superconductivity',
        'Solid \nState \nElectronics',
        'Specific \nHeat',
        'Second Law of \nThermodynamics',
        'System \nWork',
        'Specific \nHeat',
        )
# T
(
    temperature_scales,
    thermal_expansion,
    thermal_equilibrium,
    threek_background_radiation,
    temperature,
    thin_film,
    thermodynamics,
    traveling_waves,
    timbre,
    torques,
    time_dilation,
    twin_paradox
    ) = (
        'Temperature \nScales',
        'Thermal \nExpansion',
        'Thermal \nEquilibrium',
        '3K \nBackground \nRadiation',
        'Temperature',
        'Thin \nFilm',
        'Thermodynamics',
        'Traveling \nWaves',
        'Timbre',
        'Torques',
        'Time \nDilation',
        'Twin \nParadox',
        )
# U
uncertainty_principle,       = 'Uncertainty \nPrinciple'
# V
(
    voltage_law,
    vision,
    voltage,
    vector_operations,
    velocity_acceleration
    ) = (
        'Voltage \nLaw',
        'Vision',
        'Voltage',
        'Vector \nOperations',
        'Velocity & \nAcceleration',
        )
# W
(
    weinbergs_first_three_minutes,
    work_energy_power,
    work_energy_principle,
    wavefunction,
    wien_displacement_law,
    wave_particle_duality,
    white_dwarf) = (
        "Weinberg's First \nThree Minutes",
        'Work, \nEnergy, \n& Power',
        'Work-Energy \nPrinciple', 
        'Wavefunction',
        'Wien \nDisplacement \nLaw',
        'Wave-Particle \nDuality',
        'White \nDwarf',
        )
# Z
zeroth_law_of_thermodynamics = 'Zeroth Law of \nThermodynamics'
# Out:
# ('Temperature', 'Zeroth Law of Thermodynamics')

# %%
params_default = {
    'figsize': (16, 16),
    'vertex_size': 2000,
    'layout': 'spring',
}
params_interactive = {
    'method': 'js',
    'vertex_size': 25,
    'link_distance': 150,
    'charge':-500,
    'force_spring_layout': True,
}

# %%
dict_hyperphysics = {
    hyperphysics: [mechanics, electromagnetism, optics, acoustics, relativity, astrophysics, quantum, nuclear, condensed_matter, thermodynamics],
}
dict_mechanics = {
    mechanics: [conservation_laws, velocity_acceleration, circular_motion, solid_mechanics, physical_units],
    physical_units: [vector_operations,],
    solid_mechanics: [fluid_mechanics,],
    velocity_acceleration: [periodic_motion, newtons_laws],
    newtons_laws: [mass, forces, work_energy_power],
    forces: [gravity,],
    conservation_laws: [conservation_of_momentum, conservation_of_angular_momentum, conservation_of_energy],
    conservation_of_energy: [work_energy_principle, ],
    work_energy_power: [conservation_of_energy, work_energy_principle],  
    circular_motion: [orbits, ],
    orbits: [rotation, ],
    rotation: [conservation_of_angular_momentum, torques],
    torques: [conservation_of_angular_momentum, equilibrium],
}
dict_electromagnetism = {
    electromagnetism: [applications, electric_circuits, circuit_elements, electric_charge, magnetic_field, lorentz_force_law, electronics, bioelectrity],
    electric_circuits: [voltage_law, dc_circuits],
    circuit_elements: [resistor, capacitor, inductor],
    electric_charge: [coulombs_law, ],    
    voltage_law: [current_law, ],
    dc_circuits: [ohms_law, electric_power, ac_circuits, ohms_law],
    coulombs_law: [gausss_law, electric_field],
    amperes_law: [biot_savart_law, magnetic_field],
    maxwells_equations: [em_waves, lorentz_force_law],
    current_law: [ohms_law, ],
    ac_circuits: [household_wiring, ohms_law],
    biot_savart_law: [faradays_law, ],
    electric_field: [voltage, gausss_law],
    voltage: [emf, measurement, electric_current],
    electric_current: [measurement, ],
    }
dict_optics = {
    'Optics': ['Color', 'Light Intensity', 'Atmospheric Phenomena', 'Light Propagation', 'Quantum Properties', 'Polarization'],
    'Color': ['Color Vision',],
    'Light Intensity': ['Photometry',],
    'Light Propagation': ['Refraction', 'Interference', 'Diffraction', 'Reflection'],
    'Polarization': ['Scattering',],
    'Refraction': ['Lenses', "Snell's Law"],
    'Reflection': ['Mirrors',],
    'Diffraction': ['Fraunhofer',],
    'Lasers': ['Quantum Properties', 'Holography'],
    "Snell's Law": ['Index of Refraction',],
    'Thin Film': ['Interference', 'Double Slit',],
    'Holography': ['Fourier Optics',],
    'Prisms': ['Lenses', 'Optical Instruments'],
    'Mirror Instruments': ['Mirrors', 'Fiber Optics'],
    'Double Slit': ['Michelson Interferometer',],
    'Fresnel': ['Fraunhofer', 'Single Slit',],
    'Optical Instruments': ['Vision',],
    'Fiber Optics': ['Absorption',],
    'Single Slit': ['Aperture',],
    'Fabry-Perot Interferometer': ['Michelson Interferometer', 'Interference Filters'],
    'Aperture': ['Grating',],
}
dict_acoustics = {
    'Acoustics': ['Hearing', 'Sound Measurement', 'Periodic Motion', 'Sound Propagation', 'Resonance', 'Musical Instruments'],
	'Auditorium Acoustics': ['Inverse Square Law',],
	'Air Columns': ['Standing Waves', 'Musical Scales'],
	'Decibels': ['Phons',],
	'Diffraction': ['Sound Reproduction',],
	'Reflection': ['Interference',],
	'Refraction': ['Diffraction',],
	'Interference': ['Beats', 'Refraction'],
	'Sound Propagation': ['Reflection', 'Auditorium Acoustics'],
	'Sound Measurement': ['Decibels',],
	'Strings': ['Standing Waves', 'Air Columns'],
	'Pitch': ['Loudness',],
	'Phons': ['dBA',],
	'Periodic Motion': ['Traveling Waves',],
	'Pythagorean': ['Equal Tempered',],
    'Hearing': ['Pitch',],
	'Loudness': ['Timbre',],
	'Musical Instruments': ['Strings',],
	'Musical Scales': ['Pythagorean',],
    'Traveling Waves': ['Doppler Effect',],
	'Inverse Square Law': ['Reverberation',],
	'Resonance': ['Standing Waves',],
}
dict_relativity = {
    'Relativity': ['Ideas of Special Relativity', 'Experiments of Special Relativity', 'Doppler Shift', 'Ideas of General Relativity', 'Experiments of General Relativity', 'Relativistic Mechanical Quantities'],
    'Relativistic Mass': ['E=mc^2', 'Time Dilation'],
    'Lorentz Transformation': ['Length Contraction', 'Time Dilation'],
    'Galilean Transformation': ['Lorentz Transformation', 'Ideas of Special Relativity'],
    'Michelson-Morley Experiment': ['Aberration of Star-light', 'Experiments of Special Relativity'],
    'Muon Experiment': ['Relativistic Mass', 'Aberration of Starlight'],
    'Twin Paradox': ['Einstein Velocity Addition', 'Doppler Shift'],
    'Einstein Velocity Addition': ['Nuclear Binding Energy',],
    'Principle of Equivalence': ['Advance of Perihelion of Mercury', 'Ideas of General Relativity'],
    'Advance of Perihelion of Mercury': ['Gravitational Time Dilation',],
    'Gravitational Time Dilation': ['Black Holes',],
    'Experiments of General Relativity': ['Gravitational Waves',],
}
dict_astrophysics = {
    'Astrophysics': ['Solar System', 'Cosmology', 'Other Galaxies', 'Milky Way Galaxy'],
    'Contraction': ['Black Hole', 'Neutron Star'],
    'Cosmology': ["Weinberg's First Three Minutes", 'Expanding Universe'],
    'Expanding Universe': ['Density Parameter', '3K Background Radiation', 'Distance Measurement'],
    'Other Galaxies': ['Seyfert Galaxies', 'BL Lacertae Objects', 'Quasars'],
    'Supernova': ['Black Hole', 'Neutron Star'],
    'Milky Way Galaxy': ['Stars', 'Gravitational Contraction'],
    'Main Sequence': ['Red Supergiant', 'Red Giant'],
    'Red Supergiant': ['Supernova', 'Contraction'],
    'Red Giant': ['Red Giant (Pre-Nova)', 'White Dwarf'],
    'Nova': ['Red Giant (Post-Nova)', 'White Dwarf'],
    'Pre-Nova': ['Nova',],
    'Post-Nova': ['Pre-Nova',],
    '3K Background Radiation': ['H-He Abundance',],
    'Stars': ['Celestial Measurement',],
    'Seyfert Galaxies': ['Distance Measurement',],
    'BL Lacertae Objects': ['Distance Measurement',],
    'Quasars': ['Distance Measurement',],
    'Gravitational Contraction': ['Main Sequence',],
    'Neutron Star': ['Pulsar',],
    }
dict_quantum = {
    'Quantum': ['Failures of Classical Physics', 'Photoelectric Effect', 'Bohr Theory', 'Wavefunction'], 
    'Quantum Numbers': ['Hydrogen Energies',], 
    'Failures of Classical Physics': ['Planck Hypothesis', 'Wave-Particle Duality'], 
    'Photoelectric Effect': ['Compton Scattering', 'Blackbody Radiation'], 
    'Hydrogen Energies': ['Hydrogen Spectrum', 'Atomic Properties'], 
    'Schrodinger Equation': ['Hydrogen Energies', 'Particles', 'Forces'],
    'Atomic Properties': ['Periodic Table',],
    'Blackbody Radiation': ['Radiation Curves',],
    'Bohr Theory': ['Quantum Numbers',],
    'Planck Hypothesis': ['Uncertainty Principle',],
    'Radiation Curves': ['Wien Displacement Law',],
    'Uncertainty Principle': ['Quantum Statistics',],
    'Wavefunction': ['Schrodinger Equation',],
    'Wave Particle Duality': ['Uncertainty Principle',],
    'Wien Displacement Law': ['3K Background Radiation',],
    }
dict_nuclear = {
    'Nuclear': ['Nuclear Particles', 'Radioactivity', 'Nuclear Structure', 'Nuclear Reactions', 'Nuclear Energy', 'Nuclear Medicine'],
    'Nuclear Particles': ['Nuclear Notation',],
    'Nuclear Notation': ['Isotopes', 'Nuclear Forces'],
    'Nuclear Reactions': ['Nuclear Binding Energy',],
    'Nuclear Binding Energy': ['Nuclear Fission',],
    'Nuclear Fission': ['Nuclear Fusion',],
    'Nuclear Forces': ['Nuclear Size',],
    'Nuclear Structure': ['Nuclear Spectra',],
    'Nuclear Spectra': ['Particle Physics',],
    'Nuclear Size': ['Nuclear Scale Model',],
    'Nuclear Scale Model': ['Nuclear Units',],
    'Nuclear Energy': ['Nuclear Weapons', 'Light Water Reactions'],
    'Rutherford Scattering': ['Nuclear Forces', 'Nuclear Size', 'Nuclear Scale Model'],
    'Radioactivity': ['Half Life', 'Alpha', 'Beta', 'Gamma', 'Decay Paths'],
    'Half Life': ['Radiation Risk',],
    'Decay Paths': ['Radioactive Dating',],
    'Radioactive Dating': ['Radiation Detection',],
    'Light Water Reactions': ['Fast Breeder',],
    'Fast Breeder': ['Fusion Reactors',],
    }
dict_condensed_matter = {
    'Condensed Matter': ['Semiconductor Properties', 'Crystal Lattice', 'Metals', 'Electrical Properties', 'Magnetic Properties'],
    'Magnetic Properties': ['Ferromagnetism', 'Paramagnetism', 'Diamagnetism'],
    'Electrical Properties': ['Superconductivity', 'Band Theory of Solids'],
    'Band Theory of Solids': ['Dielectric Media', 'Piezoelectric Effect'],
    'Semiconductor Properties': ['Solid State Electronics',],
    'Lattice Vibrations': ['Crystal Lattice', 'Specific Heat'],
    'Metals': ['Fermi Energy',],
    'Fermi Energy': ['Electron Density',],
}
dict_thermodynamics = {
    'Thermodynamics': ['Internal Energy', 'Temperature', 'Specific Heat', 'Heat Transfer', 'Heat Engines', 'Kinetic Theory'],
    'Temperature': ['Temperature Scales',],
    'Temperature Scales': ['Thermal Expansion',],
    'Thermal Equilibrium': ['Zeroth Law of Thermodynamics',],
    'Ideal Gas Law': ['Equipartition of Energy',],
    'Internal Energy': ['Heat',],
    'Isothermal': ['Adiabatic',],
    'Heat': ['System Work',],
    'Heat Engines': ['Second Law of Thermodynamics', 'Isothermal'],
    'Heat Transfer': ['Conduction', 'Convection', 'Radiation'],
    'Second Law of Thermodynamics': ['Entropy',],
    'System Work': ['First Law of Thermodynamics',],
    'Specific Heat': ['Enthalpy',],
    'Adiabatic': ['Constant Volume',],
    'Constant Volume': ['PV Diagrams',],
    'Enthalpy': ['Phase Changes',],
    'Equipartition of Energy': ['Boltzmann Distribution',],
    'Phase Changes': ['Thermal Equilibrium',],
    'Radiation': ['Relative Humidity',],
    'Kinetic Theory': ['Ideal Gas Law',],
}

# %% [markdown]
# #### Create Individual Graphs

# %%
graph_hyperphysics = Graph(dict_hyperphysics)
graph_mechanics = Graph(dict_mechanics)
graph_electromagnetism = Graph(dict_electromagnetism)
graph_optics = Graph(dict_optics)
graph_acoustics = Graph(dict_acoustics)
graph_relativity = Graph(dict_relativity)
graph_astrophysics = Graph(dict_astrophysics)
graph_quantum = Graph(dict_quantum)
graph_nuclear = Graph(dict_nuclear)
graph_condensed_matter = Graph(dict_condensed_matter)
graph_thermodynamics = Graph(dict_thermodynamics)

# %% [markdown]
# #### Rating-Color Scale

# %%
rate = ('silver', 'red', 'orange', 'yellow', 'green', 'blue')  # ('silver', 'tomato', 'gold', 'yellowgreen', 'skyblue', 'orchid')
polys = [polygon([(0,0), (0,1), (1,1), (1,0)], axes=False, color=c) + text(f'{i +1} Star' + ('s' if i else ''), (1/2, 1/2), color='black') for i, c in enumerate(rate[1:])]
graphics_array(polys)
# Out:
# Graphics Array of size 1 x 5

# %% [markdown]
# #### Rating Assignments

# %%
ratings_hyperphysics = {
    rate[0]: [physics, ],
    rate[1]: [acoustics, ],
    rate[2]: [condensed_matter, optics],
    rate[3]: [nuclear, electromagnetism],
    rate[4]: [relativity, quantum, thermodynamics],
    rate[5]: [mechanics, astrophysics]
    }
ratings_mechanics = {
    rate[1]: [
        'Physical \nUnits',
        'Vector \nOperations', 
    ],
    rate[2]: [
        'Work, \nEnergy, \n& Power', 
        'Velocity & \nAcceleration', 
        'Mass', 
        'Torques', 
    ],
    rate[3]: [
        'Fluid \nMechanics', 
        'Solid \nMechanics', 
        'Work-Energy \nPrinciple', 
        'Orbits', 
        'Rotation', 
    ],
    rate[4]: [
        'Conservation \nof \nMomentum', 
        'Conservation of \nAngular \nMomentum', 
        'Conservation \nof \nEnergy', 
        'Periodic \nMotion', 
        'Circular \nMotion', 
    ],
    rate[5]: [
        'Forces', 
        "Newton's \nLaws", 
        'Gravity', 
        'Conservation \nLaws',        
        'Equilibrium',  
        'Mechanics', 
    ]
    }
ratings_electromagnetism = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_optics = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_acoustics = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_relativity = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_astrophysics = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_quantum = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_nuclear = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_condensed_matter = {
    rate_colors[1]: [],
    rate_colors[2]: [],
    rate_colors[3]: [],
    rate_colors[4]: [],
    rate_colors[5]: []
    }
ratings_thermodynamics = {
    rate_colors[1]: ['Heat Engines','Temperature Scales'],
    rate_colors[2]: ['Relative Humidity', 'Isothermal', 'Adiabatic', 'Enthalpy', 'Specific Heat'],
    rate_colors[3]: ['Internal Energy', 'Heat', 'System Work', 'First Law of Thermodynamics', 'Temperature', 'Constant Volume', 'Thermal Expansion', 'Kinetic Theory', 'Ideal Gas Law', 'PV Diagrams'],
    rate_colors[4]: ['Heat Transfer', 'Conduction', 'Convection', 'Radiation', 'Thermal Equilibrium', 'Zeroth Law of Thermodynamics', 'Thermodynamics'],
    rate_colors[5]: ['Second Law of Thermodynamics', 'Entropy', 'Equipartition of Energy', 'Boltzmann Distribution', 'Phase Changes']
    }

# %%
graph_hyperphysics.show(vertex_colors=ratings_hyperphysics, **params_default)
# Out:
# Graphics object consisting of 22 graphics primitives

# %%
graph_mechanics.show(vertex_colors=ratings_mechanics, **params_default)
# Out:
# Graphics object consisting of 48 graphics primitives

# %%
graph_electromagnetism.show(vertex_colors=ratings_electromagnetism, **params_default)
# Out:
# Graphics object consisting of 67 graphics primitives

# %%
graph_optics.show(vertex_colors=ratings_optics, **params_default)
# Out:
# Graphics object consisting of 74 graphics primitives

# %%
graph_acoustics.show(vertex_colors=ratings_acoustics, **params_default)
# Out:
# Graphics object consisting of 62 graphics primitives

# %%
graph_relativity.show(vertex_colors=ratings_relativity, **params_default)
# Out:
# Graphics object consisting of 50 graphics primitives

# %%
graph_astrophysics.show(vertex_colors=ratings_astrophysics, **params_default)
# Out:
# Graphics object consisting of 67 graphics primitives

# %%
graph_quantum.show(vertex_colors=ratings_quantum, **params_default)
# Out:
# Graphics object consisting of 47 graphics primitives

# %%
graph_nuclear.show(vertex_colors=ratings_nuclear, **params_default)
# Out:
# Graphics object consisting of 64 graphics primitives

# %%
graph_condensed_matter.show(vertex_colors=ratings_condensed_matter, **params_default)
# Out:
# Graphics object consisting of 36 graphics primitives

# %%
graph_thermodynamics.show(vertex_colors=ratings_thermodynamics, **params_default)
# Out:
# Graphics object consisting of 58 graphics primitives

# %%
ratings_combined = ratings_hyperphysics | ratings_mechanics | ratings_electromagnetism | ratings_optics | ratings_acoustics | ratings_relativity | ratings_astrophysics | ratings_quantum | ratings_nuclear | ratings_condensed_matter | ratings_thermodynamics
params_default['vertex_colors'] = ratings_combined
params_interactive['vertex_colors'] = ratings_combined

# %%
graph_hyperphysics = graph_physics.union(
    graph_mechanics).union(
        graph_electromagnetism).union(
            graph_optics).union(
                graph_acoustics).union(
                    graph_relativity).union(
                        graph_astrophysics).union(
                            graph_quantum).union(
                                graph_nuclear).union(
                                    graph_condensed_matter).union(
                                        graph_thermodynamics)
graph_hyperphysics.show(**params_default)
# Out:
# Graphics object consisting of 568 graphics primitives

# %%
graph_hyperphysics.show(**params_interactive)

# %% [markdown]
# ```mermaid
# graph LR
#     physics(Physics)-->mechanics(Mechanics)
# 	physics-->electromagnetism(Electromagnetism)
# 	physics-->optics(Optics)
# 	physics-->acoustics(Acoustics)
# 	physics-->relativity(Relativity)
# 	physics-->astrophysics(Astrophysics)
# 	physics-->quantum(Quantum)
#     physics-->nuclear(Nuclear)
#     physics-->condensed_matter(Condensed Matter)
# 	physics-->thermodynamics(Thermodynamics)
# ```
#
# ```mermaid
# graph LR;
# 	mechanics(Mechanics)-->conservation_laws(Conservation Laws);
# 	conservation_laws-->conservation_of_momentum(Conservation of Momentum);
# 	conservation_laws-->conservation_of_angular_momentum(Conservation of Angular Momentum);
# 	conservation_laws-->conservation_of_energy(Conservation of Energy);
#     mechanics-->velocity_acceleration(Velocity & Acceleration);
# 	velocity_acceleration-->periodic_motion(Periodic Motion);
# 	velocity_acceleration-->newtons_laws(Newton's Laws);
# 	newtons_laws-->mass(Mass);
# 	newtons_laws-->forces(Forces);
# 	forces-->gravity(Gravity);
# 	newtons_laws-->work_energy_and_power(Work, Energy, and Power);
# 	work_energy_and_power-->conservation_of_energy;
# 	work_energy_and_power-->work_energy_principle(Work-Energy Principle);
# 	conservation_of_energy-->work_energy_principle;
# 	mechanics-->circular_motion(Circular Motion);
# 	circular_motion-->orbits(Orbits);
# 	orbits-->rotation(Rotation);
# 	rotation-->torques(Torques);
# 	rotation-->conservation_of_angular_momentum;
# 	torques-->equilibrium(Equilibrium);
# 	torques-->conservation_of_angular_momentum;
# 	mechanics-->solid_mechanics(Solid Mechanics);
# 	solid_mechanics-->fluid_mechanics(Fluid Mechanics);
# 	mechanics-->physical_units(Physical Units);
# 	physical_units-->vector_operations(Vector Operations);
# ```
#
# ```mermaid
# graph LR;
# 	electromagnetism(Electromagnetism)-->applications(Applications);
# 	electromagnetism-->electric_circuits(Electric Circuits);
# 	electric_circuits-->voltage_law(Voltage Law);
# 	voltage_law-->current_law(Current Law);
# 	current_law-->ohms_law(Ohm's Law);
# 	electric_circuits-->dc_circuits(DC Circuits);
# 	dc_circuits-->ohms_law;
# 	dc_circuits-->electric_power(Electric Power);
# 	dc_circuits-->ac_circuits(AC Circuits);
# 	ac_circuits-->ohms_law;
# 	ac_circuits-->household_wiring(Household Wiring);
# 	electromagnetism-->circuit_elements(Circuit Elements);
# 	circuit_elements-->resistor(Resistor);
# 	circuit_elements-->capacitor(Capacitor);
# 	circuit_elements-->inductor(Inductor);
# 	electromagnetism-->electric_charge(Electric Charge);
# 	electric_charge-->coulombs_law(Coulomb's Law);
# 	coulombs_law-->gausss_law(Gauss's Law);
# 	gausss_law-->electric_field(Electric Field);
# 	coulombs_law-->electric_field;
# 	electric_field-->voltage(Voltage);
# 	voltage-->emf(EMF);
# 	voltage-->measurement(Measurement);
# 	voltage-->electric_current(Electric Current);
# 	electric_current-->measurement;
# 	electromagnetism-->magnetic_field(Magnetic Field);
# 	magnetic_field-->amperes_law(Ampere's Law);
# 	amperes_law-->biot_savart_law(Biot-Savart Law);
# 	biot_savart_law-->faradays_law(Faraday's Law);
# 	electromagnetism-->lorentz_force_law(Lorentz Force Law);
# 	lorentz_force_law-->maxwells_equations(Maxwell's Equations);
# 	maxwells_equations-->em_waves(EM Waves);
# 	electromagnetism-->electronics(Electronics);
# 	electromagnetism-->bioelectricity(Bioelectrity);
# ```
#
# ```mermaid
# graph LR;
# 	optics(Optics)-->color(Color);
# 	color-->color_vision(Color Vision);
# 	optics-->light_intensity(Light Intensity);
# 	light_intensity-->photometry(Photometry);
# 	optics-->atmospheric_phenomena(Atmospheric Phenomena);
# 	optics-->light_propagation(Light Propagation);
# 	light_propagation-->refraction(Refraction);
# 	refraction-->lenses(Lenses);
# 	lenses-->prisms(Prisms);
# 	prisms-->optical_instruments(Optical Instruments);
# 	optical_instruments-->vision(Vision);
# 	refraction-->snells_law(Snell's Law);
# 	snells_law-->index_of_refraction(Index of Refraction);
# 	light_propagation-->reflection(Reflection);
# 	reflection-->mirrors(Mirrors);
# 	mirrors-->mirror_instruments(Mirror Instruments);
# 	mirror_instruments-->fiber_optics(Fiber Optics);
# 	fiber_optics-->absorption(Absorption);
# 	light_propagation-->interference(Interference);
# 	interference-->thin_film(Thin Film);
# 	thin_film-->double_slit(Double Slit);
# 	double_slit-->michelson_interferometer(Michelson Interferometer);
# 	michelson_interferometer-->fabry_perot_interferometer(Fabry-Perot Interferometer);
# 	fabry_perot_interferometer-->interference_filters(Interference Filters);
# 	light_propagation-->diffraction(Diffraction);
# 	diffraction-->fraunhofer(Fraunhofer);
# 	fraunhofer-->fresnel(Fresnel);
# 	fresnel-->single_slit(Single Slit);
# 	single_slit-->aperture(Aperture);
# 	aperture-->grating(Grating);
# 	optics-->quantum_properties(Quantum Properties);
# 	quantum_properties-->lasers(Lasers);
# 	lasers-->holography(Holography);
# 	holography-->fourier_optics(Fourier Optics);
# 	optics-->polarization(Polarization);
# 	polarization-->scattering(Scattering);
# ```
#
# ```mermaid
# graph LR;
# 	acoustics(Acoustics)-->hearing(Hearing);
# 	hearing-->pitch(Pitch);
# 	pitch-->loudness(Loudness);
# 	loudness-->timbre(Timbre);
# 	acoustics-->sound_measurement(Sound Measurement);
# 	sound_measurement-->decibels(Decibels);
# 	decibels-->phons(Phons);
# 	phons-->dba(dBA);
# 	acoustics-->periodic_motion(Periodic Motion);
# 	periodic_motion-->traveling_waves(Traveling Waves);
# 	traveling_waves-->doppler_effect(Doppler Effect);
# 	acoustics-->sound_propagation(Sound Propagation);
# 	sound_propagation-->reflection(Reflection);
# 	reflection-->interference(Interference);
# 	interference-->beats(Beats);
# 	interference-->refraction(Refraction);
# 	refraction-->diffraction(Diffraction);
# 	diffraction-->sound_reproduction(Sound Reproduction);
# 	sound_propagation-->auditorium_acoustics(Auditorium Acoustics);
# 	auditorium_acoustics-->inverse_square_law(Inverse Square Law);
# 	inverse_square_law-->reverberation(Reverberation);
# 	acoustics-->resonance(Resonance);
# 	resonance-->standing_waves(Standing Waves);
# 	acoustics-->musical_instruments(Musical Instruments);
# 	musical_instruments-->strings(Strings);
# 	strings-->standing_waves;
# 	strings-->air_columns(Air Columns);
# 	air_columns-->standing_waves;
# 	air_columns-->musical_scales(Musical Scales);
# 	musical_scales-->pythagorean(Pythagorean);
# 	pythagorean-->equal_tempered(Equal Tempered);
# ```
#
# ```mermaid
# graph LR;
# 	relativity(Relativity)-->ideas_of_special_relativity(Ideas of Special Relativity);
# 	ideas_of_special_relativity-->galilean_transformation(Galilean Transformation);
# 	galilean_transformation-->lorentz_transformation(Lorentz Transformation);
# 	lorentz_transformation-->length_contraction(Length Contraction);
# 	lorentz_transformation-->time_dilation(Time Dilation);
# 	time_dilation-->relativistic_mass(Relativistic Mass);
# 	relativistic_mass-->emc2(E=mc^2);
# 	relativity-->experiments_of_special_relativity(Experiments of Special Relativity);
# 	experiments_of_special_relativity-->michelson_morley_experiment(Michelson-Morley Experiment);
# 	michelson_morley_experiment-->aberration_of_starlight(Aberration of Star-light);
# 	aberration_of_starlight-->muon_experiment(Muon Experiment);
# 	muon_experiment-->relativistic_mass;
# 	relativity-->doppler_shift(Doppler Shift);
# 	doppler_shift-->twin_paradox(Twin Paradox);
# 	twin_paradox-->einstein_velocity_addition(Einstein Velocity Addition);
# 	einstein_velocity_addition-->nuclear_binding_energy(Nuclear Binding Energy);
# 	relativity-->ideas_of_general_relativity(Ideas of General Relativity);
# 	ideas_of_general_relativity-->principle_of_equivalence(Principle of Equivalence);
# 	principle_of_equivalence-->advance_of_perihelion_of_mercury(Advance of Perihelion of Mercury);
# 	advance_of_perihelion_of_mercury-->gravitational_time_dilation(Gravitational Time Dilation);
# 	gravitational_time_dilation-->black_holes(Black Holes);
# 	relativity-->experiments_of_general_relativity(Experiments of General Relativity);
# 	experiments_of_general_relativity-->gravitational_waves(Gravitational Waves);
# 	relativity-->relativistic_mechanical_quantities(Relativistic Mechanical Quantities);
# ```
#
# ```mermaid
# graph LR;
# 	astrophysics(Astrophysics)-->solar_system(Solar System);
# 	astrophysics-->cosmology(Cosmology);
# 	cosmology-->weinbergs_first_three_minutes(Weinberg's First Three Minutes);
# 	cosmology-->expanding_universe(Expanding Universe);
# 	expanding_universe-->density_parameter(Density Parameter);
# 	expanding_universe-->3k_background_radiation(3K Background Radiation);
# 	3k_background_radiation-->h_he_abundance(H-He Abundance);
# 	expanding_universe-->distance_measurement(Distance Measurement);
# 	astrophysics-->other_galaxies(Other Galaxies);
# 	other_galaxies-->seyfert_galaxies(Seyfert Galaxies);
# 	other_galaxies-->bl_lacertae_objects(BL Lacertae Objects);
# 	other_galaxies-->quasars(Quasars);
# 	seyfert_galaxies-->distance_measurement;
# 	bl_lacertae_objects-->distance_measurement;
# 	quasars-->distance_measurement;
# 	astrophysics-->milky_way_galaxy(Milky Way Galaxy);
# 	milky_way_galaxy-->stars(Stars);
# 	stars-->celestial_measurement(Celestial Measurement);
# 	milky_way_galaxy-->gravitational_contraction(Gravitational Contraction);
# 	gravitational_contraction-->main_sequence(Main Sequence);
# 	main_sequence-->red_supergiant(Red Supergiant);
# 	red_supergiant-->supernova(Supernova);
# 	supernova-->black_hole(Black Hole);
# 	supernova-->neutron_star(Neutron Star);
# 	red_supergiant-->contraction(Contraction);
# 	contraction-->black_hole;
# 	contraction-->neutron_star;
# 	neutron_star-->pulsar(Pulsar);
# 	main_sequence-->red_giant(Red Giant);
# 	red_giant-->pre_nova(Red Giant Pre-Nova);
# 	pre_nova-->nova(Nova);
# 	nova-->post_nova(Red Giant Post-Nova);
# 	post_nova-->pre_nova;
# 	nova-->white_dwarf(White Dwarf);
# 	red_giant-->white_dwarf;
# ```
#
# ```mermaid
# graph LR;
# 	quantum(Quantum)-->failures_of_classical_physics(Failures of Classical Physics);
# 	failures_of_classical_physics-->planck_hypothesis(Planck Hypothesis);
# 	failures_of_classical_physics-->wave_particle_duality(Wave-Particle Duality);
# 	wave_particle_duality-->uncertainty_principle(Uncertainty Principle);
# 	planck_hypothesis-->uncertainty_principle;
# 	uncertainty_principle-->quantum_statistics(Quantum Statistics);
# 	quantum-->photoelectric_effect(Photoelectric Effect);
# 	photoelectric_effect-->compton_scattering(Compton Scattering);
# 	photoelectric_effect-->blackbody_radiation(Blackbody Radiation);
# 	blackbody_radiation-->radiation_curves(Radiation Curves);
# 	radiation_curves-->wien_displacement_law(Wien Displacement Law);
# 	wien_displacement_law-->3k_background_radiation(3K Background Radiation);
# 	quantum-->bohr_theory(Bohr Theory);
# 	bohr_theory-->quantum_numbers(Quantum Numbers);
# 	quantum_numbers-->hydrogen_energies(Hydrogen Energies);
# 	hydrogen_energies-->hydrogen_spectrum(Hydrogen Spectrum);
# 	hydrogen_energies-->atomic_properties(Atomic Properties);
# 	atomic_properties-->periodic_table(Periodic Table);
# 	quantum-->wavefunction(Wavefunction);
# 	wavefunction-->schrodinger_equation(Schrodinger Equation);
# 	schrodinger_equation-->hydrogen_energies;
# 	schrodinger_equation-->particles(Particles);
# 	schrodinger_equation-->forces(Forces);
# ```
#
# ```mermaid
# graph LR;
#     nuclear(Nuclear)-->nuclear_particles(Nuclear Particles);
# 	nuclear_particles-->nuclear_notation(Nuclear Notation);
# 	nuclear_notation-->isotopes(Isotopes);
# 	nuclear_notation-->nuclear_forces(Nuclear Forces);
# 	nuclear_forces-->nuclear_size(Nuclear Size);
# 	nuclear_size-->nuclear_scale_model(Nuclear Scale Model);
# 	nuclear_scale_model-->nuclear_units(Nuclear Units);
# 	rutherford_scattering(Rutherford Scattering)-->nuclear_forces;
# 	rutherford_scattering-->nuclear_size;
# 	rutherford_scattering-->nuclear_scale_model;
# 	nuclear-->radioactivity(Radioactivity);
# 	radioactivity-->half_life(Half Life);
# 	half_life-->radiation_risk(Radiation Risk);
# 	radioactivity-->alpha(Alpha);
# 	radioactivity-->beta(Beta);
# 	radioactivity-->gamma(Gamma);
# 	radioactivity-->decay_paths(Decay Paths);
# 	decay_paths-->radioactive_dating(Radioactive Dating);
# 	radioactive_dating-->radiation_detection(Radiation Detection);
# 	nuclear-->nuclear_structure(Nuclear Structure);
# 	nuclear_structure-->nuclear_spectra(Nuclear Spectra);
# 	nuclear_spectra-->particle_physics(Particle Physics);
#     nuclear-->nuclear_reactions(Nuclear Reactions);
# 	nuclear_reactions-->nuclear_binding_energy(Nuclear Binding Energy);
# 	nuclear_binding_energy-->nuclear_fission(Nuclear Fission);
# 	nuclear_fission-->nuclear_fusion(Nuclear Fusion);
#     nuclear-->nuclear_energy(Nuclear Energy);
# 	nuclear_energy-->nuclear_weapons(Nuclear Weapons);
# 	nuclear_energy-->light_water_reactions(Light Water Reactions);
# 	light_water_reactions-->fast_breeder(Fast Breeder);
# 	fast_breeder-->fusion_reactors(Fusion Reactors);
#     nuclear-->nuclear_medicine(Nuclear Medicine);
# ```
#
# ```mermaid
# graph LR;
#     condensed_matter(Condensed Matter)-->semiconductor_properties(Semiconductor Properties);
# 	semiconductor_properties-->solid_state_electronics(Solid State Electronics);
# 	condensed_matter-->crystal_lattice(Crystal Lattice);
# 	crystal_lattice-->lattice_vibrations(Lattice Vibrations);
# 	lattice_vibrations-->specific_heat(Specific Heat);
# 	condensed_matter-->metals(Metals);
# 	metals-->fermi_energy(Fermi Energy);
# 	fermi_energy-->electron_density(Electron Density);
# 	condensed_matter-->electrical_properties(Electrical Properties);
# 	electrical_properties-->superconductivity(Superconductivity);
# 	electrical_properties-->band_theory_of_solids(Band Theory of Solids);
# 	band_theory_of_solids-->dielectric_media(Dielectric Media);
# 	band_theory_of_solids-->piezoelectric_effect(Piezoelectric Effect);
# 	condensed_matter-->magnetic_properties(Magnetic Properties);
# 	magnetic_properties-->ferromagnetism(Ferromagnetism);
# 	magnetic_properties-->paramagnetism(Paramagnetism);
# 	magnetic_properties-->diamagnetism(Diamagnetism);
# ```
#
# ```mermaid
# graph LR;
# 	thermodynamics(Thermodynamics)-->internal_energy(Internal Energy);
# 	internal_energy-->heat(Heat);
# 	heat-->system_work(System Work);
# 	system_work-->first_law_of_thermodynamics(First Law of Thermodynamics);
# 	thermodynamics-->temperature(Temperature);
# 	temperature-->temperature_scales(Temperature Scales);
# 	temperature_scales-->thermal_expansion(Thermal Expansion);
# 	thermodynamics-->specific_heat(Specific Heat);
# 	specific_heat-->enthalpy(Enthalpy);
# 	enthalpy-->phase_changes(Phase Changes);
# 	phase_changes-->thermal_equilibrium(Thermal Equilibrium);
# 	thermal_equilibrium-->zeroth_law_of_thermodynamics(Zeroth Law of Thermodynamics);
# 	thermodynamics-->heat_transfer(Heat Transfer);
# 	heat_transfer-->conduction(Conduction);
# 	heat_transfer-->convection(Convection);
# 	heat_transfer-->radiation(Radiation);
# 	radiation-->relative_humidity(Relative Humidity);
# 	thermodynamics-->heat_engines(Heat Engines);
# 	heat_engines-->second_law_of_thermodynamics(Second Law of Thermodynamics);
# 	second_law_of_thermodynamics-->entropy(Entropy);
# 	heat_engines-->isothermal(Isothermal);
# 	isothermal-->adiabatic(Adiabatic);
# 	adiabatic-->constant_volume(Constant Volume);
# 	constant_volume-->pv_diagrams(PV Diagrams);
# 	thermodynamics-->kinetic_theory(Kinetic Theory);
# 	kinetic_theory-->ideal_gas_law(Ideal Gas Law);
# 	ideal_gas_law-->equipartition_of_energy(Equipartition of Energy);
# 	equipartition_of_energy-->boltzmann_distribution(Boltzmann Distribution);
# ```

# %% [markdown]
# <table>
# <tr>
#    	<th>Theory</th>
#    	<th>Topic</th>
# 	<th>Concept</th>
# </tr>
# <tr>
# 	<td rowspan="7">Mechanics</td>
# 	<td>Biomechanics, Aerodynamics, Classical Mechanics, Homeokinetics, Kinematics, Dynamics, Statics, Continuum Mechanics, Celestial Mechanics, chaos theory, acoustics</td>
# 	<td>Galilean invariance, conservation laws, harmonic oscillator, Tait–Bryan angles, Euler angles, Virial theorem, Newton's theorem of revolving orbits</td>
# </tr>
# <tr>
# 	<td rowspan="3">Analytical Mechanics: Noether's theorem, Stationary-action principle, Generalized Lagrangian mean, Legendre transformation</td>
# 	<td>Newtonian Mechanics</td>
# </tr>
# <tr>
# 	<td>Lagrangian Mechanics</td>
# </tr>
# <tr>
# 	<td>Hamiltonian Mechanics</td>
# </tr>
# <tr>
# 	<td rowspan="3">Fluid Mechanics: Navier–Stokes Equations</td>
# 	<td>Fluid Dynamics</td>
# </tr>
# <tr>
# 	<td>Fluid Kinematics</td>
# </tr>
# <tr>
# 	<td>Fluid Statics</td>
# </tr>
# <tr>
# 	<td>Electromagnetism</td>
# 	<td>Electrostatics, electrodynamics, electricity, magnetism, magnetostatics, Maxwell's equations, optics</td>
# 	<td>induction, radiation, Gaussian surface, flux, monopole</td>
# </tr>
# <tr>
# 	<td>Thermodynamics and Statistical Mechanics</td>
# 	<td>Heat engine, kinetic theory, Non-Equilibrium Mechanics</td>
# 	<td>conjugate variables, enthalpy, entropy, equation of state, equipartition theorem, thermodynamic free energy, laws of thermodynamics, Maxwell relations, Ising model, mechanical action, partition function, state function, statistical ensemble, Thermodynamic limit</td>
# </tr>
# <tr>
# 	<td>Quantum Mechanics</td>
# 	<td>Quantum Foundations, Quantum Information Theory, Quantum Field theory, Path integral formulation, scattering theory, Schrödinger Equation, Dirac Equation, Quantum Statistical Mechanics, Quantum Electrodynamics, Quantum Chromodynamics</td>
# 	<td>The Photoelectric Effect, Wave-Particle Duality, Wavefunction, Matrix Mechanics, Uncertainty Principle, Relativistic Quantum Mechanics, Adiabatic approximation, black-body radiation, correspondence principle, free particle, Hamiltonian, Hilbert space, identical particles, observer effect, quantum entanglement, quantum harmonic oscillator, quantum tunneling, Dirac equation, wave mechanics, zero-point energy, Pauli Exclusion Principle, Wave function collapse, Observer (Effect), Path integral formulation, Perturbation theory, Classical limit, Classical probability density, Coherence, Quantum non-equilibrium, Quantum pseudo-telepathy, Quantum gravity, Loop quantum gravity, String theory, QED vacuum, Spin foam, quantum gravity, Theory of Everything, Grand Unified Theory, (Super)Symmetry</td>
# </tr>
# <tr>
# 	<td>Relativity</td>
# 	<td>Special relativity, general relativity, Einstein field equations</td>
# 	<td>Quantum gravity, Covariance, Einstein manifold, equivalence principle, geodesic motion, gravity, gravitoelectromagnetism, inertial frame of reference, invariance, Lorentzian manifold, Lorentz transformation, mass–energy equivalence, metric, Minkowski diagram, Minkowski space, simultaneity, spacetime, speed of light, Frame-dragging, Holographic principle, Gravitational waves, Spatiotemporal resolution, Tensor network, Lorentz scalar, Metric tensor</td>
# </tr>
# <tr>
# 	<td>Particle Physics</td>
# 	<td>Accelerator physics, nuclear physics, nuclear astrophysics, particle astrophysics, particle physics phenomenology</td>
# 	<td>Standard Model, quantum field theory, quantum chromodynamics, electroweak theory, effective field theory, lattice field theory, lattice gauge theory, gauge theory, supersymmetry, Grand Unified Theory, superstring theory, M-theory, antimatter, Ternary fission, fusion, Radioactivity, Radioactive decay, Antimatter</td>
# <tr>
# 	<td>Atomic, molecular, and optical physics</td>
# 	<td>Atomic physics, molecular physics, atomic and molecular astrophysics, chemical physics, optics, photonics</td>
# 	<td>Quantum optics, quantum chemistry, quantum information science, lasers, polarization, Casimir effect, reflection, refraction, diffraction, interference</td>
# </tr>
# <tr>
# 	<td>Condensed matter physics</td>
# 	<td>Solid state physics, high pressure physics, low-temperature physics, nanoscale/mesoscopic physics, polymer physics</td>
# 	<td>BCS theory, Bloch's theorem, Fermi gas, Fermi liquid, many-body theory, Bose–Einstein condensate, superfluid, self-organization, (spontaneous) symmetry breaking, Phase transitions, Supercooling, Nanotechnology, Superconductivity</td>
# </tr>
# <tr>
# 	<td>Astrophysics</td>
# 	<td>Cosmology, Stellar Astronomy, Planetary Science, Physical Cosmology, Galactic Astronomy, Extragalactic Astronomy, Celestial Mechanics, Cosmology, gravitation physics, high-energy astrophysics, planetary astrophysics, plasma physics, space physics, stellar astrophysics</td>
# 	<td>Quantum fluctuation, Big Bang, Lambda-CDM model, cosmic inflation, general relativity, law of universal gravitation, Black holes, cosmic background radiation, cosmic strings, dark energy, dark matter, singularity, supernovae</td>
# </tr>
# <tr>
# 	<td>Interdisciplinary Branches</td>
# 	<td>Robotics, Plasma Physics, Astronomy (Astrodynamics, Astrometry, Astrobiology), Atmospheric Physics, Biophysics (Neurophysics, Quantum Biology), Chemical Physics/Physical Chemistry, Computational Physics, Geophysics, Materials Physics/Science, Mathematical Physics, Medical Physics, Ocean Physics/Physical Oceanography, Quantum Information Science, Philosophy of Physics, Psychophysics, Agrophysics, Space Physics, Econophysics, Environmental Physics, Engineering Physics, Quantum Computing, Sociophysics, Cryophysics/Cryogenics, Vehicle Dynamics</td>
# 	<td>Atmospheric pressure photoionization, Flotation of flexible objects, Mass versus weight, Asymptotic safety in quantum gravity, Covariant formulation of classical electromagnetism, Active and passive transformation, Causality, Quantum mind, Quantum brain dynamics</td>
# </tr>
# <tr>
# 	<td>Misc.</td>
# 	<td>Classical: Pressure physics, Chaos theory, Canonical quantization; Modern: Kinematic chain, Classical/Modern states, Plasma Physics, Transport Phenomena, Annihilation physics, Vacuum state physics, Stochastic process, Electroweak theory, Complex/Dynamical systems; Interdisciplinary: Combustion, Brownian motion, Observable universe, Multiverse, Emergence</td>
# 	<td>Ansatz, First principles, Coherent turbulent structure, Contracted Bianchi identities, Covariance group, Ergodic hypothesis, Euclidean vector, Gravitational contact terms, Hyperuniformity, Lorenz gauge condition, Mean-field theory, Negative frequency, Potentiometric surface, Quasistatic approximation, Relative locality, Relativistic heat conduction, Self-organization, Super Bloch oscillations, Sznajd model, Variable structure system, Free/Point/Virtual particles, Wigner–Weyl transform, Polynomial Wigner–Ville distribution, Wigner quasiprobability distribution, Maxwell–Boltzmann statistics, Bose–Einstein statistics, Vector potential, Vector space, State space, Phase space, Phase (matter), Phase space crystals</td>
# </tr>
#
# </table>
#
#
# __Notes__
# ---
# 1. "If, in some cataclysm, all of scientific knowledge were to be destroyed, and only one sentence passed on to the next generations ..., what statement would contain the most information in the fewest words? I believe it is [...] that _all things are made up of atoms – little particles that move around in perpetual motion, attracting each other when they are a little distance apart, but repelling upon being squeezed into one another. ..._" - Richard Feynman
# 4. "Physical science is that department of knowledge which relates to the order of nature, or, in other words, to the regular succession of events.", "Physical science is that department of knowledge which relates to the order of nature, or, in other words, to the regular succession of events." - J. C. Maxwell
# 5. "Physics is an _experimental_ science. Physicists observe the phenomena of nature and try to find patterns and principles that relate these phenomena. These patterns are called physical theories or, when they are very well established and of broad use, physical laws or principles." - Young & Freedman
#
# __References__
# ---
# 1. Feynman, R.P.; Leighton, R.B.; Sands, M. (1963). _The Feynman Lectures on Physics_. Vol. 1. ISBN 978-0-201-02116-5.
# 2. Maxwell, J.C. (1878). _Matter and Motion_. D. Van Nostrand. ISBN 978-0-486-66895-6. "matter and motion."
# 3. Perot, Pierre (1998). _A to Z of Thermodynamics_. Oxford University Press. ISBN 978-0-19-856552-9.
# 6. Van Ness, H.C. (1969). _Understanding Thermodynamics_. Dover Publications, Inc. ISBN 978-0-486-63277-3.
# 7. Dugdale, J. S. (1998). _Entropy and its Physical Meaning_. Taylor and Francis. ISBN 978-0-7484-0569-5.
# 8. Landau and Lifshitz (1951, 1962), _The Classical Theory of Fields_, Library of Congress Card Number 62-9181, Chapters 1–4 (3rd edition is ISBN 0-08-016019-0)
# 9. Edmund Taylor Whittaker (1904). _A Treatise on the Analytical Dynamics of Particles and Rigid Bodies_. Cambridge University Press. ISBN 978-0-521-35883-5.
# 10. Joseph Stiles Beggs (1983). _Kinematics_. Taylor & Francis. p. 1. ISBN 978-0-89116-355-8.
# 11. Thomas Wallace Wright (1896). _Elements of Mechanics Including Kinematics, Kinetics and Statics_. E and FN Spon. Chapter 1.
# 12. Corson and Lorrain, _Electromagnetic Fields and Waves_ ISBN 0-7167-1823-5
#
# __External Links__
# ---
# - AIP.org is the website of the American Institute of Physics
# - IOP.org is the website of the Institute of Physics
# - APS.org is the website of the American Physical Society
# - SPS National is the website of the American Society of Physics Students
# - CAP.ca is the website of the Canadian Association of Physicists
# - EPS.org is the website of the European Physical Society
# - Meta Institute for Computational Physics - Popular Talks
# - ScienceMathMastery - Compilation of YouTube Physics Courses
# - Physics | Channel | MIT Video
# - How to become a GOOD Theoretical Physicist, a website with outline of theoretical physics by Gerard 't Hooft
# - Resource recommendations - List of freely available physics books - Physics Stack Exchange
