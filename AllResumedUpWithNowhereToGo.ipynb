# %% [markdown]
# # Outline $\circ$ Branches $\circ$ Concepts $\circ$ Topics $\circ$ Physics (x)

# %% [markdown]
# __Physics__ – natural science that involves the study of matter and its motion through spacetime, along with related concepts such as energy and force. More broadly, it is the general analysis of nature, conducted in order to understand how the universe behaves. a scientific discipline that seeks to construct and experimentally test theories of the physical universe. The solution of tractable problems in nature.
#
# __Universe__ - everything that physically exists: the entirety of space and time, all forms of matter, energy and momentum, and the physical laws and constants that govern them. However, the term 'universe' may also be used in slightly different contextual senses, denoting concepts such as the cosmos or the philosophical world.

# %% [markdown]
# #### ["You just gotta tighten up the bolts a little bit" - Sips](https://youtu.be/9653yNP0pYk?t=6740)

# %% [markdown]
# #### Original HyperPhysics Network Diagrams

# %%
from IPython.display import Image, SVG
# import ipywidgets as widgets

# widgets.ToggleButtons(
#     options=[r'\(1 \star\)', '2 Stars', '3 Stars', '****', '5 Stars'],
#     description='Score:',
#     disabled=False,
#     button_style='primary', # 'success', 'info', 'warning', 'danger' or ''
#     tooltips=[r'\(\star\)', 'Description of regular', 'Description of fast'],
# #     icons=['check'] * 3
# )

# score_slider = widgets.IntSlider(
#     value=3,
#     min=0,
#     max=5,
#     step=1,
#     description='Score: ',
#     disabled=False,
#     continuous_update=False,
#     orientation='horizontal',
#     readout=True,
#     readout_format='d'
# )

# widgets.HBox([score_slider, widgets.Label(value=r"\(\star's\)")])

# %%
# Source: 'http://hyperphysics.phy-astr.gsu.edu/hbase/'
original_graph_hyperphysics = Image('./Photos/HyperPhysics/Hyperphysics.gif')
original_graph_electromagnetism = Image('./Photos/HyperPhysics/Electromagnetism/Electromagnetism.gif')
original_graph_optics = Image('./Photos/HyperPhysics/Optics/Optics.gif')
original_graph_mechanics = Image('./Photos/HyperPhysics/Mechanics/Mechanics.gif')
original_graph_acoustics = Image('./Photos/HyperPhysics/Acoustics/Acoustics.gif')
original_graph_thermodynamics = Image('./Photos/HyperPhysics/Thermodynamics/Thermodynamics.gif')
original_graph_relativity = Image('./Photos/HyperPhysics/Relativity/Relativity.gif')
original_graph_condensed_matter = Image('./Photos/HyperPhysics/CondensedMatter/CondensedMatter.gif')
original_graph_astrophysics = Image('./Photos/HyperPhysics/Astrophysics/Astrophysics.png')
original_graph_nuclear = Image('./Photos/HyperPhysics/Nuclear/Nuclear.png')
original_graph_quantum = Image('./Photos/HyperPhysics/Quantum/QuantumPhysics.gif')

# %% [markdown]
# #### Recreations Using ```mermaid```

# %%
mermaid_graph_hyperphysics = Image('./Photos/Mermaid/Physics/HyperPhysics.png')
mermaid_graph_electromagnetism = Image('./Photos/Mermaid/Physics/Electromagnetism.png')
mermaid_graph_optics = Image('./Photos/Mermaid/Physics/Optics.png')
mermaid_graph_mechanics = Image('./Photos/Mermaid/Physics/Mechanics.png')
mermaid_graph_acoustics = Image('./Photos/Mermaid/Physics/Acoustics.png')
mermaid_graph_thermodynamics = Image('./Photos/Mermaid/Physics/Thermodynamics.png')
mermaid_graph_relativity = Image('./Photos/Mermaid/Physics/Relativity.png')
mermaid_graph_condensed_matter = Image('./Photos/Mermaid/Physics/CondensedMatter.png')
mermaid_graph_astrophysics = Image('./Photos/Mermaid/Physics/Astrophysics.png')
mermaid_graph_nuclear = Image('./Photos/Mermaid/Physics/Nuclear.png')
mermaid_graph_quantum = Image('./Photos/Mermaid/Physics/QuantumPhysics.png')

# %% [markdown]
# #### Rating-Color Scale

# %%
default_colors = ('silver', 'tomato', 'gold', 'yellowgreen', 'skyblue', 'orchid')
rate = ('silver', 'red', 'orange', 'yellow', 'green', 'blue')  # 
polys = [polygon([(0,0), (0,1), (1,1), (1,0)], axes=False, color=c) + text(f'{i +1} Star' + ('s' if i else ''), (1/2, 1/2), color='black') for i, c in enumerate(rate[1:])]
graphics_array(polys)
# Out:
# Graphics Array of size 1 x 5

# %% [markdown]
# ##### Hard-Coding Labels

# %%
class CategoryLabel:
    def __init__(self, label, score=0, color=None, color_pallete=default_colors):
        self.label = label
        self.score = score
        self._color = color
        self.color_pallete = color_pallete
        self.__repr__, self.__str__ = self.label, self.label
    
    @property
    def color(self):
        if self._color is None:
            self._color = self.color_pallete[self.score]
        return self._color

# %%
# A
aberration_of_starlight          = CategoryLabel('Aberration \nof \nStarlight',              )
absorption                       = CategoryLabel('Absorption',                               )
acoustics                        = CategoryLabel('Acoustics',                                )
ac_circuits                      = CategoryLabel('AC \nCircuits',                            )
adiabatic                        = CategoryLabel('Adiabatic',                                )
advance_of_perihelion_of_mercury = CategoryLabel('Advance \nof \nPerihelion \nof \nMercury', )
air_columns                      = CategoryLabel('Air \nColumns',                            )
alpha                            = CategoryLabel('Alpha',                                    )
amperes_law                      = CategoryLabel("Ampere's \nLaw",                           )
aperture                         = CategoryLabel('Aperture',                                 )
applications                     = CategoryLabel('Applications',                             )
astrophysics                     = CategoryLabel('Astrophysics',                             )
atmospheric_phenomena            = CategoryLabel('Atmospheric \nPhenomena',                  )
atomic_properties                = CategoryLabel('Atomic \nProperties',                      )
auditorium_acoustics             = CategoryLabel('Auditorium \nAcoustics',                   )

# %%
# B
band_theory_of_solids  = CategoryLabel('Band \nTheory \nof \nSolids',  )
beta                   = CategoryLabel('Beta',                         )
beats                  = CategoryLabel('Beats',                        )
bioelectrity           = CategoryLabel('Bioelectrity',                 )
biot_savart_law        = CategoryLabel('Biot-Savart \nLaw',            )
blackbody_radiation    = CategoryLabel('Blackbody \nRadiation',        )
black_hole             = CategoryLabel('Black \nHole',                 )
black_holes            = CategoryLabel('Black \nHoles',                )
bl_lacertae_objects    = CategoryLabel('BL \nLacertae \nObjects',      )
bohr_theory            = CategoryLabel('Bohr \nTheory',                )
boltzmann_distribution = CategoryLabel('Boltzmann \nDistribution',     )

# %%
# C
contraction                      = CategoryLabel('Contraction',                            )
color                            = CategoryLabel('Color',                                  )
color_vision                     = CategoryLabel('Color \nVision',                         )
circular_motion                  = CategoryLabel('Circular \nMotion',                      )
circuit_elements                 = CategoryLabel('Circuit \nElements',                     )
condensed_matter                 = CategoryLabel('Condensed \nMatter',                     )
capacitor                        = CategoryLabel('Capacitor',                              )
coulombs_law                     = CategoryLabel("Coulomb's \nLaw",                        )
current_law                      = CategoryLabel('Current \nLaw',                          )
conservation_laws                = CategoryLabel('Conservation \nLaws',                    )
conservation_of_energy           = CategoryLabel('Conservation \nof \nEnergy',             )
constant_volume                  = CategoryLabel('Constant \nVolume',                      )
conservation_of_momentum         = CategoryLabel('Conservation \nof \nMomentum',           )
conservation_of_angular_momentum = CategoryLabel('Conservation \nof \nAngular \nMomentum', )
compton_scattering               = CategoryLabel('Compton \nScattering',                   )
conduction                       = CategoryLabel('Conduction',                             )
convection                       = CategoryLabel('Convection',                             )
crystal_lattice                  = CategoryLabel('Crystal \nLattice',                      )
celestial_measurement            = CategoryLabel('Celestial \nMeasurement',                )
cosmology                        = CategoryLabel('Cosmology',                              )

# %%
# D
decay_paths          = CategoryLabel('Decay \nPaths',          )
density_parameter    = CategoryLabel('Density \nParameter',    )
distance_measurement = CategoryLabel('Distance \nMeasurement', )
dc_circuits          = CategoryLabel('DC \nCircuits',          )
diamagnetism         = CategoryLabel('Diamagnetism',           )
dielectric_media     = CategoryLabel('Dielectric \nMedia',     )
double_slit          = CategoryLabel('Double \nSlit',          )
diffraction          = CategoryLabel('Diffraction',            )
decibels             = CategoryLabel('Decibels',               )
doppler_shift        = CategoryLabel('Doppler \nShift',        )
dba                  = CategoryLabel('dBA',                    )
doppler_effect       = CategoryLabel('Doppler \nEffect',       )

# %%
# E
emc2                              = CategoryLabel('E=mc^2',                                  )
experiments_of_general_relativity = CategoryLabel('Experiments \nof \nGeneral \nRelativity', )
experiments_of_special_relativity = CategoryLabel('Experiments \nof \nSpecial \nRelativity', )
einstein_velocity_addition        = CategoryLabel('Einstein \nVelocity \nAddition',          )
equal_tempered                    = CategoryLabel('Equal \nTempered',                        )
equilibrium                       = CategoryLabel('Equilibrium',                             )
electric_circuits                 = CategoryLabel('Electric \nCircuits',                     )
electric_charge                   = CategoryLabel('Electric \nCharge',                       )
electric_current                  = CategoryLabel('Electric \nCurrent',                      )
electric_field                    = CategoryLabel('Electric \nField',                        )
electric_power                    = CategoryLabel('Electric \nPower',                        )
electromagnetism                  = CategoryLabel('Electromagnetism',                        )
electronics                       = CategoryLabel('Electronics',                             )
em_waves                          = CategoryLabel('EM \nWaves',                              )
emf                               = CategoryLabel('EMF',                                     )
electrical_properties             = CategoryLabel('Electrical \nProperties',                 )
expanding_universe                = CategoryLabel('Expanding \nUniverse',                    )
electron_density                  = CategoryLabel('Electron \nDensity',                      )
entropy                           = CategoryLabel('Entropy',                                 )
enthalpy                          = CategoryLabel('Enthalpy',                                )
equipartition_of_energy           = CategoryLabel('Equipartition \nof \nEnergy',             )

# %%
# F
first_law_of_thermodynamics   = CategoryLabel('First \nLaw \nof \nThermodynamics',   )
fermi_energy                  = CategoryLabel('Fermi \nEnergy',                      )
ferromagnetism                = CategoryLabel('Ferromagnetism',                      )
failures_of_classical_physics = CategoryLabel('Failures \nof \nClassical \nPhysics', )
fast_breeder                  = CategoryLabel('Fast \nBreeder',                      )
fusion_reactors               = CategoryLabel('Fusion \nReactors',                   )
fluid_mechanics               = CategoryLabel('Fluid \nMechanics',                   )
fabry_perot_interferometer    = CategoryLabel('Fabry-Perot \nInterferometer',        )
fraunhofer                    = CategoryLabel('Fraunhofer',                          )
fourier_optics                = CategoryLabel('Fourier \nOptics',                    )
fiber_optics                  = CategoryLabel('Fiber \nOptics',                      )
fresnel                       = CategoryLabel('Fresnel',                             )
faradays_law                  = CategoryLabel("Faraday's \nLaw",                     )
forces                        = CategoryLabel('Forces',                              )

# %%
# G
gravity                     = CategoryLabel('Gravity',                         )
gamma                       = CategoryLabel('Gamma',                           )
galilean_transformation     = CategoryLabel('Galilean \nTransformation',       )
gravitational_contraction   = CategoryLabel('Gravitational \nContraction',     )
gravitational_time_dilation = CategoryLabel('Gravitational \nTime \nDilation', )
gravitational_waves         = CategoryLabel('Gravitational \nWaves',           )
grating                     = CategoryLabel('Grating',                         )
gausss_law                  = CategoryLabel("Gauss's \nLaw",                   )

# %%
# H
hearing           = CategoryLabel('Hearing',             )
hydrogen_energies = CategoryLabel('Hydrogen \nEnergies', )
hydrogen_spectrum = CategoryLabel('Hydrogen \nSpectrum', )
heat              = CategoryLabel('Heat',                )
heat_engines      = CategoryLabel('Heat \nEngines',      )
heat_transfer     = CategoryLabel('Heat \nTransfer',     )
holography        = CategoryLabel('Holography',          )
hyperphysics      = CategoryLabel('HyperPhysics',        )
household_wiring  = CategoryLabel('Household \nWiring',  )
half_life         = CategoryLabel('Half \nLife',         )
h_he_abundance    = CategoryLabel('H-He \nAbundance',    )

# %%
# I
inductor                    = CategoryLabel('Inductor',                          )
inverse_square_law          = CategoryLabel('Inverse \nSquare \nLaw',            )
interference                = CategoryLabel('Interference',                      )
isotopes                    = CategoryLabel('Isotopes',                          )
ideas_of_special_relativity = CategoryLabel('Ideas \nof \nSpecial \nRelativity', )
ideas_of_general_relativity = CategoryLabel('Ideas \nof \nGeneral \nRelativity', )
internal_energy             = CategoryLabel('Internal \nEnergy',                 )
isothermal                  = CategoryLabel('Isothermal',                        )
ideal_gas_law               = CategoryLabel('Ideal \nGas \nLaw',                 )
interference_filters        = CategoryLabel('Interference \nFilters',            )
index_of_refraction         = CategoryLabel('Index \nof \nRefraction',           )

# %%
# K
kinetic_theory = CategoryLabel('Kinetic \nTheory', )

# %%
# L
lorentz_transformation = CategoryLabel('Lorentz \nTransformation',  )
lattice_vibrations     = CategoryLabel('Lattice \nVibrations',      )
lorentz_force_law      = CategoryLabel("Lorentz' \nForce \nLaw",    )
light_water_reactions  = CategoryLabel('Light \nWater \nReactions', )
loudness               = CategoryLabel('Loudness',                  )
lasers                 = CategoryLabel('Lasers',                    )
lenses                 = CategoryLabel('Lenses',                    )
light_intensity        = CategoryLabel('Light \nIntensity',         )
light_propagation      = CategoryLabel('Light \nPropagation',       )
length_contraction     = CategoryLabel('Length \nContraction',      )

# %%
# M
michelson_morley_experiment = CategoryLabel('Michelson-Morley \nExperiment', )
musical_instruments         = CategoryLabel('Musical \nInstruments', )
musical_scales              = CategoryLabel('Musical \nScales', )
muon_experiment             = CategoryLabel('Muon \nExperiment', )
main_sequence               = CategoryLabel('Main \nSequence', )
milky_way_galaxy            = CategoryLabel('Milky \nWay \nGalaxy', )
mechanics                   = CategoryLabel('Mechanics', )
metals                      = CategoryLabel('Metals', )
magnetic_properties         = CategoryLabel('Magnetic \nProperties',  )
mirrors                     = CategoryLabel('Mirrors', )
mirror_instruments          = CategoryLabel('Mirror \nInstruments', )
michelson_interferometer    = CategoryLabel('Michelson \nInterferometer', )
magnetic_field              = CategoryLabel('Magnetic \nField', )
maxwells_equations          = CategoryLabel("Maxwell's \nEquations", )
measurement                 = CategoryLabel('Measurement', )
mass                        = CategoryLabel('Mass', )

# %%
# N
nuclear                = CategoryLabel('Nuclear',                      )
nuclear_particles      = CategoryLabel('Nuclear \nParticles',          )
nuclear_structure      = CategoryLabel('Nuclear \nStructure',          )
nuclear_reactions      = CategoryLabel('Nuclear \nReactions',          )
nuclear_energy         = CategoryLabel('Nuclear \nEnergy',             )
nuclear_medicine       = CategoryLabel('Nuclear \nMedicine',           )
nuclear_notation       = CategoryLabel('Nuclear \nNotation',           )
nuclear_forces         = CategoryLabel('Nuclear \nForces',             )
nuclear_binding_energy = CategoryLabel('Nuclear \nBinding \nEnergy',   )
nuclear_fission        = CategoryLabel('Nuclear \nFission',            )
nuclear_fusion         = CategoryLabel('Nuclear \nFusion',             )
nuclear_size           = CategoryLabel('Nuclear \nSize',               )
nuclear_spectra        = CategoryLabel('Nuclear \nSpectra',            )
nuclear_scale_model    = CategoryLabel('Nuclear \nScale \nModel',      )
nuclear_units          = CategoryLabel('Nuclear \nUnits',              )
nova                   = CategoryLabel('Nova',                         )
nuclear_weapons        = CategoryLabel('Nuclear \nWeapons',            )
neutron_star           = CategoryLabel('Neutron \nStar',               )
nuclear_binding_energy = CategoryLabel('Nuclear \nBinding \nEnergy',   )
newtons_laws           = CategoryLabel("Newton's \nLaws",              )

# %%
# O
orbits              = CategoryLabel('Orbits',                )
other_galaxies      = CategoryLabel('Other \nGalaxies',      )
optics              = CategoryLabel('Optics',                )
ohms_law            = CategoryLabel("Ohm's \nLaw",           )
optical_instruments = CategoryLabel('Optical \nInstruments', )

# %%
# P
pre_nova                 = CategoryLabel('Pre-Nova',                     )
post_nova                = CategoryLabel('Post-Nova',                    )
pulsar                   = CategoryLabel('Pulsar',                       )
planck_hypothesis        = CategoryLabel('Planck \nHypothesis',          )
photoelectric_effect     = CategoryLabel('Photoelectric \nEffect',       )
particles                = CategoryLabel('Particles',                    )
particle_physics         = CategoryLabel('Particle \nPhysics',           )
piezoelectric_effect     = CategoryLabel('Piezoelectric \nEffect',       )
paramagnetism            = CategoryLabel('Paramagnetism',                )
periodic_table           = CategoryLabel('Periodic \nTable',             )
pv_diagrams              = CategoryLabel('PV \nDiagrams',                )
phase_changes            = CategoryLabel('Phase \nChanges',              )
photometry               = CategoryLabel('Photometry',                   )
prisms                   = CategoryLabel('Prisms',                       )
polarization             = CategoryLabel('Polarization',                 )
periodic_motion          = CategoryLabel('Periodic \nMotion',            )
phons                    = CategoryLabel('Phons',                        )
pitch                    = CategoryLabel('Pitch',                        )
pythagorean              = CategoryLabel('Pythagorean',                  )
physical_units           = CategoryLabel('Physical \nUnits',             )
principle_of_equivalence = CategoryLabel('Principle \nof \nEquivalence', )

# %%
# Q
quantum_properties = CategoryLabel('Quantum \nProperties', )
quantum            = CategoryLabel('Quantum',              )
quantum_numbers    = CategoryLabel('Quantum \nNumbers',    )
quantum_statistics = CategoryLabel('Quantum \nStatistics', )
quasars            = CategoryLabel('Quasars',              )

# %%
# R
red_giant_post_nova                = CategoryLabel('Red \nGiant \n(Post-Nova)',              )
radiation                          = CategoryLabel('Radiation',                              )
relative_humidity                  = CategoryLabel('Relative \nHumidity',                    )
red_giant                          = CategoryLabel('Red \nGiant',                            )
red_giant_pre_nova                 = CategoryLabel('Red \nGiant \n(Pre-Nova)',               )
red_supergiant                     = CategoryLabel('Red \nSupergiant',                       )
radiation_risk                     = CategoryLabel('Radiation \nRisk',                       )
radiation_curves                   = CategoryLabel('Radiation \nCurves',                     )
radioactivity                      = CategoryLabel('Radioactivity',                          )
radioactive_dating                 = CategoryLabel('Radioactive \nDating',                   )
radiation_detection                = CategoryLabel('Radiation \nDetection',                  )
rutherford_scattering              = CategoryLabel('Rutherford \nScattering',                )
resistor                           = CategoryLabel('Resistor',                               )
refraction                         = CategoryLabel('Refraction',                             )
reflection                         = CategoryLabel('Reflection',                             )
rotation                           = CategoryLabel('Rotation',                               )
resonance                          = CategoryLabel('Resonance',                              )
relativistic_mechanical_quantities = CategoryLabel('Relativistic \nMechanical \nQuantities', )
relativity                         = CategoryLabel('Relativity',                             )
reverberation                      = CategoryLabel('Reverberation',                          )
relativistic_mass                  = CategoryLabel('Relativistic \nMass',                    )

# %%
# S
snells_law                   = CategoryLabel("Snell's \nLaw",                      )
single_slit                  = CategoryLabel('Single \nSlit',                      )
scattering                   = CategoryLabel('Scattering',                         )
sound_propagation            = CategoryLabel('Sound \nPropagation',                )
sound_reproduction           = CategoryLabel('Sound \nReproduction',               )
standing_waves               = CategoryLabel('Standing \nWaves',                   )
strings                      = CategoryLabel('Strings',                            )
solar_system                 = CategoryLabel('Solar \nSystem',                     )
seyfert_galaxies             = CategoryLabel('Seyfert \nGalaxies',                 )
sound_measurement            = CategoryLabel('Sound \nMeasurement',                )
supernova                    = CategoryLabel('Supernova',                          )
stars                        = CategoryLabel('Stars',                              )
semiconductor_properties     = CategoryLabel('Semiconductor \nProperties',         )
schrodinger_equation         = CategoryLabel('Schrodinger \nEquation',             )
solid_mechanics              = CategoryLabel('Solid \nMechanics',                  )
superconductivity            = CategoryLabel('Superconductivity',                  )
solid_state_electronics      = CategoryLabel('Solid \nState \nElectronics',        )
specific_heat                = CategoryLabel('Specific \nHeat',                    )
second_law_of_thermodynamics = CategoryLabel('Second \nLaw \nof \nThermodynamics', )
system_work                  = CategoryLabel('System \nWork',                      )

# %%
# T
temperature_scales          = CategoryLabel('Temperature \nScales',        )
thermal_expansion           = CategoryLabel('Thermal \nExpansion',         )
thermal_equilibrium         = CategoryLabel('Thermal \nEquilibrium',       )
threek_background_radiation = CategoryLabel('3K \nBackground \nRadiation', )
temperature                 = CategoryLabel('Temperature',                 )
thin_film                   = CategoryLabel('Thin \nFilm',                 )
thermodynamics              = CategoryLabel('Thermodynamics',              ) 
traveling_waves             = CategoryLabel('Traveling \nWaves',           )
timbre                      = CategoryLabel('Timbre',                      )
torques                     = CategoryLabel('Torques',                     )
time_dilation               = CategoryLabel('Time \nDilation',             )
twin_paradox                = CategoryLabel('Twin \nParadox',              )

# %%
# U
uncertainty_principle = CategoryLabel('Uncertainty \nPrinciple', )

# %%
# V
voltage_law           = CategoryLabel('Voltage \nLaw',               )
vision                = CategoryLabel('Vision',                      )
voltage               = CategoryLabel('Voltage',                     )
vector_operations     = CategoryLabel('Vector \nOperations',         )
velocity_acceleration = CategoryLabel('Velocity \n& \nAcceleration', )

# %%
# W
weinbergs_first_three_minutes = CategoryLabel("Weinberg's \nFirst \nThree \nMinutes", )
work_energy_power             = CategoryLabel('Work, \nEnergy, \n& \nPower',          )
work_energy_principle         = CategoryLabel('Work-Energy \nPrinciple',              )
wavefunction                  = CategoryLabel('Wavefunction',                         )
wien_displacement_law         = CategoryLabel('Wien \nDisplacement \nLaw',            )
wave_particle_duality         = CategoryLabel('Wave-Particle \nDuality',              )
white_dwarf                   = CategoryLabel('White \nDwarf',                        )

# %%
# Z
zeroth_law_of_thermodynamics = CategoryLabel('Zeroth \nLaw \nof \nThermodynamics', )

# %%
zeroth_law_of_thermodynamics

# %%
params_default = {
    'figsize': (16, 16),
    'vertex_size': 2000,
    'layout': 'spring',
}
params_interactive = {
    'method': 'js',
    'vertex_size': 25,
    'link_distance': 150,
    'charge':-500,
    'force_spring_layout': True,
}

# %%
dict_hyperphysics = {
    hyperphysics.label: [
        mechanics.label, 
        electromagnetism.label, 
        optics.label, 
        acoustics.label, 
        relativity.label, 
        astrophysics.label, 
        quantum.label, 
        nuclear.label, 
        condensed_matter.label, 
        thermodynamics.label
        ],
}
dict_mechanics = {
    mechanics.label: [
        conservation_laws.label, 
        velocity_acceleration.label, 
        circular_motion.label, 
        solid_mechanics.label, 
        physical_units.label
        ],
    physical_units.label: [
        vector_operations.label,
        ],
    solid_mechanics.label: [
        fluid_mechanics.label,
        ],
    velocity_acceleration.label: [
        periodic_motion.label, 
        newtons_laws.label,
        ],
    newtons_laws.label: [
        mass.label, 
        forces.label, 
        work_energy_power.label,
        ],
    forces.label: [
        gravity.label,
        ],
    conservation_laws.label: [
        conservation_of_momentum.label, 
        conservation_of_angular_momentum.label, 
        conservation_of_energy.label,
        ],
    conservation_of_energy.label: [
        work_energy_principle.label,
        ],
    work_energy_power.label: [
        conservation_of_energy.label, 
        work_energy_principle.label,
        ],  
    circular_motion.label: [
        orbits.label,
        ],
    orbits.label: [
        rotation.label,
        ],
    rotation.label: [
        conservation_of_angular_momentum.label,
        torques.label,
        ],
    torques.label: [
        conservation_of_angular_momentum.label,
        equilibrium.label,
        ],
}
dict_electromagnetism = {
    electromagnetism.label: [
        applications.label, 
        electric_circuits.label, 
        circuit_elements.label, 
        electric_charge.label, 
        magnetic_field.label, 
        lorentz_force_law.label, 
        electronics.label, 
        bioelectrity.label,
        ],
    electric_circuits.label: [
        voltage_law.label, 
        dc_circuits.label,
        ],
    circuit_elements.label: [
        resistor.label, 
        capacitor.label, 
        inductor.label,
        ],
    electric_charge.label: [
        coulombs_law.label,
        ],    
    voltage_law.label: [
        current_law.label,
        ],
    dc_circuits.label: [
        ohms_law.label, 
        electric_power.label, 
        ac_circuits.label, 
        ohms_law.label,
        ],
    coulombs_law.label: [
        gausss_law.label, 
        electric_field.label,
        ],
    amperes_law.label: [
        biot_savart_law.label, 
        magnetic_field.label,
        ],
    maxwells_equations.label: [
        em_waves.label, 
        lorentz_force_law.label,
        ],
    current_law.label: [
        ohms_law.label,
        ],
    ac_circuits.label: [
        household_wiring.label,
        ohms_law.label,
        ],
    biot_savart_law.label: [
        faradays_law.label,
        ],
    electric_field.label: [
        voltage.label,
        gausss_law.label,
        ],
    voltage.label: [
        emf.label,
        measurement.label,
        electric_current.label,
        ],
    electric_current.label: [
        measurement.label,
        ],
    }
dict_optics = {
    optics.label: [
        color.label, 
        light_intensity.label, 
        atmospheric_phenomena.label, 
        light_propagation.label, 
        quantum_properties.label, 
        polarization.label,
        ],
    color.label: [
        color_vision.label,
        ],
    light_intensity.label: [
        photometry.label,
        ],
    light_propagation.label: [
        refraction.label, 
        interference.label, 
        diffraction.label, 
        reflection.label,
        ],
    polarization.label: [
        scattering.label,
        ],
    refraction.label: [
        lenses.label, 
        snells_law.label,
        ],
    reflection.label: [
        mirrors.label,
        ],
    diffraction.label: [
        fraunhofer.label,
        ],
    lasers.label: [
        quantum_properties.label, 
        holography.label,
        ],
    snells_law.label: [
        index_of_refraction.label,
        ],
    thin_film.label: [
        interference.label, 
        double_slit.label,
        ],
    holography.label: [
        fourier_optics.label,
        ],
    prisms.label: [
        lenses.label, 
        optical_instruments.label,
        ],
    mirror_instruments.label: [
        mirrors.label, 
        fiber_optics.label,
        ],
    double_slit.label: [
        michelson_interferometer.label,
        ],
    fresnel.label: [
        fraunhofer.label, 
        single_slit.label,
        ],
    optical_instruments.label: [
        vision.label,
        ],
    fiber_optics.label: [
        absorption.label,
        ],
    single_slit.label: [
        aperture.label,
        ],
    fabry_perot_interferometer.label: [
        michelson_interferometer.label, 
        interference_filters.label,
        ],
    aperture.label: [
        grating.label,
        ],
}
dict_acoustics = {
    acoustics.label: [
        hearing.label, 
        sound_measurement.label, 
        periodic_motion.label, 
        sound_propagation.label, 
        resonance.label, 
        musical_instruments.label,
        ],
	auditorium_acoustics.label: [
        inverse_square_law.label,
        ],
	air_columns.label: [
        standing_waves.label, 
        musical_scales.label,
        ],
	decibels.label: [
        phons.label,
        ],
	diffraction.label: [
        sound_reproduction.label,
        ],
	reflection.label: [
        interference.label,
        ],
	refraction.label: [
        diffraction.label,
        ],
	interference.label: [
        beats.label, 
        refraction.label,
        ],
	sound_propagation.label: [
        reflection.label, 
        auditorium_acoustics.label,
        ],
	sound_measurement.label: [
        decibels.label,
        ],
	strings.label: [
        standing_waves.label, 
        air_columns.label,
        ],
	pitch.label: [
        loudness.label,
        ],
	phons.label: [
        dba.label,
        ],
	periodic_motion.label: [
        traveling_waves.label,
        ],
	pythagorean.label: [
        equal_tempered.label,
        ],
    hearing.label: [
        pitch.label,
        ],
	loudness.label: [
        timbre.label,
        ],
	musical_instruments.label: [
        strings.label,
        ],
	musical_scales.label: [
        pythagorean.label,
        ],
    traveling_waves.label: [
        doppler_effect.label,
        ],
	inverse_square_law.label: [
        reverberation.label,
        ],
	resonance.label: [
        standing_waves.label,
        ],
}
dict_relativity = {
    relativity.label: [
        ideas_of_special_relativity.label, 
        experiments_of_special_relativity.label, 
        doppler_shift.label, 
        ideas_of_general_relativity.label, 
        experiments_of_general_relativity.label, 
        relativistic_mechanical_quantities.label,
        ],
    relativistic_mass.label: [
        emc2.label, 
        time_dilation.label,
        ],
    lorentz_transformation.label: [
        length_contraction.label, 
        time_dilation.label,
        ],
    galilean_transformation.label: [
        lorentz_transformation.label, 
        ideas_of_special_relativity.label,
        ],
    michelson_morley_experiment.label: [
        aberration_of_starlight.label, 
        experiments_of_special_relativity.label,
        ],
    muon_experiment.label: [
        relativistic_mass.label, 
        aberration_of_starlight.label,
        ],
    twin_paradox.label: [
        einstein_velocity_addition.label, 
        doppler_shift.label,
        ],
    einstein_velocity_addition.label: [
        nuclear_binding_energy.label,
        ],
    principle_of_equivalence.label: [
        advance_of_perihelion_of_mercury.label, 
        ideas_of_general_relativity.label,
        ],
    advance_of_perihelion_of_mercury.label: [
        gravitational_time_dilation.label,
        ],
    gravitational_time_dilation.label: [
        black_holes.label,
        ],
    experiments_of_general_relativity.label: [
        gravitational_waves.label,
        ],
}
dict_astrophysics = {
    astrophysics.label: [
        solar_system.label, 
        cosmology.label, 
        other_galaxies.label, 
        milky_way_galaxy.label,
        ],
    contraction.label: [
        black_hole.label, 
        neutron_star.label,
        ],
    cosmology.label: [
        weinbergs_first_three_minutes.label, 
        expanding_universe.label,
        ],
    expanding_universe.label: [
        density_parameter.label, 
        threek_background_radiation.label, 
        distance_measurement.label,
        ],
    other_galaxies.label: [
        seyfert_galaxies.label, 
        bl_lacertae_objects.label, 
        quasars.label,
        ],
    supernova.label: [
        black_hole.label, 
        neutron_star.label,
        ],
    milky_way_galaxy.label: [
        stars.label, 
        gravitational_contraction.label,
        ],
    main_sequence.label: [
        red_supergiant.label, 
        red_giant.label,
        ],
    red_supergiant.label: [
        supernova.label, 
        contraction.label,
        ],
    red_giant.label: [
        red_giant_pre_nova.label, 
        white_dwarf.label,
        ],
    nova.label: [
        red_giant_post_nova.label, 
        white_dwarf.label,
        ],
    pre_nova.label: [
        nova.label,
        ],
    post_nova.label: [
        pre_nova.label,
        ],
    threek_background_radiation.label: [
        h_he_abundance.label,
        ],
    stars.label: [
        celestial_measurement.label,
        ],
    seyfert_galaxies.label: [
        distance_measurement.label,
        ],
    bl_lacertae_objects.label: [
        distance_measurement.label,
        ],
    quasars.label: [
        distance_measurement.label,
        ],
    gravitational_contraction.label: [
        main_sequence.label,
        ],
    neutron_star.label: [
        pulsar.label,
        ],
    }
dict_quantum = {
    quantum.label: [
        failures_of_classical_physics.label, 
        photoelectric_effect.label, 
        bohr_theory.label, 
        wavefunction.label,
        ], 
    quantum_numbers.label: [
        hydrogen_energies.label,
        ], 
    failures_of_classical_physics.label: [
        planck_hypothesis.label, 
        wave_particle_duality.label,
        ], 
    photoelectric_effect.label: [
        compton_scattering.label, 
        blackbody_radiation.label,
        ], 
    hydrogen_energies.label: [
        hydrogen_spectrum.label, 
        atomic_properties.label,
        ], 
    schrodinger_equation.label: [
        hydrogen_energies.label, 
        particles.label, 
        forces.label,
        ],
    atomic_properties.label: [
        periodic_table.label,
        ],
    blackbody_radiation.label: [
        radiation_curves.label,
        ],
    bohr_theory.label: [
        quantum_numbers.label,
        ],
    planck_hypothesis.label: [
        uncertainty_principle.label,
        ],
    radiation_curves.label: [
        wien_displacement_law.label,
        ],
    uncertainty_principle.label: [
        quantum_statistics.label,
        ],
    wavefunction.label: [
        schrodinger_equation.label,
        ],
    wave_particle_duality.label: [
        uncertainty_principle.label,
        ],
    wien_displacement_law.label: [
        threek_background_radiation.label,
        ],
    }
dict_nuclear = {
    nuclear.label: [
        nuclear_particles.label, 
        radioactivity.label, 
        nuclear_structure.label, 
        nuclear_reactions.label, 
        nuclear_energy.label, 
        nuclear_medicine.label,
        ],
    nuclear_particles.label: [
        nuclear_notation.label,
        ],
    nuclear_notation.label: [
        isotopes.label, 
        nuclear_forces.label,
        ],
    nuclear_reactions.label: [
        nuclear_binding_energy.label,
        ],
    nuclear_binding_energy.label: [
        nuclear_fission.label,
        ],
    nuclear_fission.label: [
        nuclear_fusion.label,
        ],
    nuclear_forces.label: [
        nuclear_size.label,
        ],
    nuclear_structure.label: [
        nuclear_spectra.label,
        ],
    nuclear_spectra.label: [
        particle_physics.label,
        ],
    nuclear_size.label: [
        nuclear_scale_model.label,
        ],
    nuclear_scale_model.label: [
        nuclear_units.label,
        ],
    nuclear_energy.label: [
        nuclear_weapons.label, 
        light_water_reactions.label,
        ],
    rutherford_scattering.label: [
        nuclear_forces.label, 
        nuclear_size.label, 
        nuclear_scale_model.label,
        ],
    radioactivity.label: [
        half_life.label, 
        alpha.label, 
        beta.label, 
        gamma.label, 
        decay_paths.label,
        ],
    half_life.label: [
        radiation_risk.label,
        ],
    decay_paths.label: [
        radioactive_dating.label,
        ],
    radioactive_dating.label: [
        radiation_detection.label,
        ],
    light_water_reactions.label: [
        fast_breeder.label,
        ],
    fast_breeder.label: [
        fusion_reactors.label,
        ],
    }
dict_condensed_matter = {
    condensed_matter.label: [
        semiconductor_properties.label, 
        crystal_lattice.label, 
        metals.label, 
        electrical_properties.label, 
        magnetic_properties.label,
        ],
    magnetic_properties.label: [
        ferromagnetism.label, 
        paramagnetism.label, 
        diamagnetism.label,
        ],
    electrical_properties.label: [
        superconductivity.label, 
        band_theory_of_solids.label,
        ],
    band_theory_of_solids.label: [
        dielectric_media.label, 
        piezoelectric_effect.label,
        ],
    semiconductor_properties.label: [
        solid_state_electronics.label,
        ],
    lattice_vibrations.label: [
        crystal_lattice.label, 
        specific_heat.label,
        ],
    metals.label: [
        fermi_energy.label,
        ],
    fermi_energy.label: [
        electron_density.label,
        ],
}
dict_thermodynamics = {
    thermodynamics.label: [
        internal_energy.label, 
        temperature.label, 
        specific_heat.label, 
        heat_transfer.label, 
        heat_engines.label, 
        kinetic_theory.label,
        ],
    temperature.label: [
        temperature_scales.label,
        ],
    temperature_scales.label: [
        thermal_expansion.label,
        ],
    thermal_equilibrium.label: [
        zeroth_law_of_thermodynamics.label,
        ],
    ideal_gas_law.label: [
        equipartition_of_energy.label,
        ],
    internal_energy.label: [
        heat.label,
        ],
    isothermal.label: [
        adiabatic.label,
        ],
    heat.label: [
        system_work.label,
        ],
    heat_engines.label: [
        second_law_of_thermodynamics.label, 
        isothermal.label,
        ],
    heat_transfer.label: [
        conduction.label, 
        convection.label, 
        radiation.label,
        ],
    second_law_of_thermodynamics.label: [
        entropy.label,
        ],
    system_work.label: [
        first_law_of_thermodynamics.label,
        ],
    specific_heat.label: [
        enthalpy.label,
        ],
    adiabatic.label: [
        constant_volume.label,
        ],
    constant_volume.label: [
        pv_diagrams.label,
        ],
    enthalpy.label: [
        phase_changes.label,
        ],
    equipartition_of_energy.label: [
        boltzmann_distribution.label,
        ],
    phase_changes.label: [
        thermal_equilibrium.label,
        ],
    radiation.label: [
        relative_humidity.label,
        ],
    kinetic_theory.label: [
        ideal_gas_law.label,
        ],
}

# %% [markdown]
# #### Create Individual Graphs

# %%
graph_hyperphysics = Graph(dict_hyperphysics)
graph_mechanics = Graph(dict_mechanics)
graph_electromagnetism = Graph(dict_electromagnetism)
graph_optics = Graph(dict_optics)
graph_acoustics = Graph(dict_acoustics)
graph_relativity = Graph(dict_relativity)
graph_astrophysics = Graph(dict_astrophysics)
graph_quantum = Graph(dict_quantum)
graph_nuclear = Graph(dict_nuclear)
graph_condensed_matter = Graph(dict_condensed_matter)
graph_thermodynamics = Graph(dict_thermodynamics)

# %% [markdown]
# #### Rating Assignments

# %%
ratings_electromagnetism = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_optics = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_acoustics = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_relativity = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_astrophysics = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_quantum = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_nuclear = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_condensed_matter = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }


ratings_hyperphysics = {
    rate[0]: [hyperphysics.label, ],
    rate[1]: [acoustics.label, ],
    rate[2]: [condensed_matter.label, optics.label],
    rate[3]: [nuclear.label, electromagnetism.label],
    rate[4]: [relativity.label, quantum.label, thermodynamics.label],
    rate[5]: [mechanics.label, astrophysics.label]
    }
ratings_mechanics = {
    rate[1]: [physical_units.label, vector_operations.label, ],
    rate[2]: [work_energy_power.label, velocity_acceleration.label, mass.label, torques.label, ],
    rate[3]: [fluid_mechanics.label, solid_mechanics.label, work_energy_principle.label, orbits.label, rotation.label, ],
    rate[4]: [conservation_of_momentum.label, conservation_of_angular_momentum.label, conservation_of_energy.label, periodic_motion.label, circular_motion.label, ],
    rate[5]: [forces.label, newtons_laws.label, gravity.label, conservation_laws.label, equilibrium.label, mechanics.label, ]
    }

ratings_thermodynamics = {
    rate[1]: [heat_engines.label, temperature_scales.label],
    rate[2]: [relative_humidity.label, isothermal.label, adiabatic.label, enthalpy.label, specific_heat.label],
    rate[3]: [internal_energy.label, heat.label, system_work.label, first_law_of_thermodynamics.label, temperature.label, constant_volume.label, thermal_expansion.label, kinetic_theory.label, ideal_gas_law.label, pv_diagrams.label],
    rate[4]: [heat_transfer.label, conduction.label, convection.label, radiation.label, thermal_equilibrium.label, zeroth_law_of_thermodynamics.label, thermodynamics.label],   
    rate[5]: [second_law_of_thermodynamics.label, entropy.label, equipartition_of_energy.label, boltzmann_distribution.label, phase_changes.label]
    }

# %%
graph_hyperphysics.show(vertex_colors=ratings_hyperphysics, **params_default)
# Out:
# Graphics object consisting of 22 graphics primitives

# %%
graph_mechanics.show(vertex_colors=ratings_mechanics, **params_default)
# Out:
# Graphics object consisting of 48 graphics primitives

# %%
graph_electromagnetism.show(vertex_colors=ratings_electromagnetism, **params_default)
# Out:
# Graphics object consisting of 67 graphics primitives

# %%
graph_optics.show(vertex_colors=ratings_optics, **params_default)
# Out:
# Graphics object consisting of 74 graphics primitives

# %%
graph_acoustics.show(vertex_colors=ratings_acoustics, **params_default)
# Out:
# Graphics object consisting of 62 graphics primitives

# %%
graph_relativity.show(vertex_colors=ratings_relativity, **params_default)
# Out:
# Graphics object consisting of 49 graphics primitives

# %%
graph_astrophysics.show(vertex_colors=ratings_astrophysics, **params_default)
# Out:
# Graphics object consisting of 67 graphics primitives

# %%
graph_quantum.show(vertex_colors=ratings_quantum, **params_default)
# Out:
# Graphics object consisting of 46 graphics primitives

# %%
graph_nuclear.show(vertex_colors=ratings_nuclear, **params_default)
# Out:
# Graphics object consisting of 64 graphics primitives

# %%
graph_condensed_matter.show(vertex_colors=ratings_condensed_matter, **params_default)
# Out:
# Graphics object consisting of 36 graphics primitives

# %%
graph_thermodynamics.show(vertex_colors=ratings_thermodynamics, **params_default)
# Out:
# Graphics object consisting of 58 graphics primitives

# %%
ratings_combined = (((((((((
    ratings_hyperphysics | ratings_mechanics
    ) | ratings_electromagnetism
    ) | ratings_optics
    ) | ratings_acoustics
    ) | ratings_relativity
    ) | ratings_astrophysics
    ) | ratings_quantum
    ) | ratings_nuclear
    ) | ratings_condensed_matter
    ) | ratings_thermodynamics
params_default['vertex_colors'] = ratings_combined
params_interactive['vertex_colors'] = ratings_combined

# %%
graph_hyperphysics = graph_hyperphysics.union(
    graph_mechanics).union(
        graph_electromagnetism).union(
            graph_optics).union(
                graph_acoustics).union(
                    graph_relativity).union(
                        graph_astrophysics).union(
                            graph_quantum).union(
                                graph_nuclear).union(
                                    graph_condensed_matter).union(
                                        graph_thermodynamics)
graph_hyperphysics.show(**params_default)
# Out:
# Graphics object consisting of 564 graphics primitives

# %%
graph_hyperphysics.show(**params_interactive)

# %% [markdown]
# <table>
# <tr>
#    	<th>Theory</th>
#    	<th>Topic</th>
# 	<th>Concept</th>
# </tr>
# <tr>
# 	<td rowspan="7">Mechanics</td>
# 	<td>Biomechanics, Aerodynamics, Classical Mechanics, Homeokinetics, Kinematics, Dynamics, Statics, Continuum Mechanics, Celestial Mechanics, chaos theory, acoustics</td>
# 	<td>Galilean invariance, conservation laws, harmonic oscillator, Tait–Bryan angles, Euler angles, Virial theorem, Newton's theorem of revolving orbits</td>
# </tr>
# <tr>
# 	<td rowspan="3">Analytical Mechanics: Noether's theorem, Stationary-action principle, Generalized Lagrangian mean, Legendre transformation</td>
# 	<td>Newtonian Mechanics</td>
# </tr>
# <tr>
# 	<td>Lagrangian Mechanics</td>
# </tr>
# <tr>
# 	<td>Hamiltonian Mechanics</td>
# </tr>
# <tr>
# 	<td rowspan="3">Fluid Mechanics: Navier–Stokes Equations</td>
# 	<td>Fluid Dynamics</td>
# </tr>
# <tr>
# 	<td>Fluid Kinematics</td>
# </tr>
# <tr>
# 	<td>Fluid Statics</td>
# </tr>
# <tr>
# 	<td>Electromagnetism</td>
# 	<td>Electrostatics, electrodynamics, electricity, magnetism, magnetostatics, Maxwell's equations, optics</td>
# 	<td>induction, radiation, Gaussian surface, flux, monopole</td>
# </tr>
# <tr>
# 	<td>Thermodynamics and Statistical Mechanics</td>
# 	<td>Heat engine, kinetic theory, Non-Equilibrium Mechanics</td>
# 	<td>conjugate variables, enthalpy, entropy, equation of state, equipartition theorem, thermodynamic free energy, laws of thermodynamics, Maxwell relations, Ising model, mechanical action, partition function, state function, statistical ensemble, Thermodynamic limit</td>
# </tr>
# <tr>
# 	<td>Quantum Mechanics</td>
# 	<td>Quantum Foundations, Quantum Information Theory, Quantum Field theory, Path integral formulation, scattering theory, Schrödinger Equation, Dirac Equation, Quantum Statistical Mechanics, Quantum Electrodynamics, Quantum Chromodynamics</td>
# 	<td>The Photoelectric Effect, Wave-Particle Duality, Wavefunction, Matrix Mechanics, Uncertainty Principle, Relativistic Quantum Mechanics, Adiabatic approximation, black-body radiation, correspondence principle, free particle, Hamiltonian, Hilbert space, identical particles, observer effect, quantum entanglement, quantum harmonic oscillator, quantum tunneling, Dirac equation, wave mechanics, zero-point energy, Pauli Exclusion Principle, Wave function collapse, Observer (Effect), Path integral formulation, Perturbation theory, Classical limit, Classical probability density, Coherence, Quantum non-equilibrium, Quantum pseudo-telepathy, Quantum gravity, Loop quantum gravity, String theory, QED vacuum, Spin foam, quantum gravity, Theory of Everything, Grand Unified Theory, (Super)Symmetry</td>
# </tr>
# <tr>
# 	<td>Relativity</td>
# 	<td>Special relativity, general relativity, Einstein field equations</td>
# 	<td>Quantum gravity, Covariance, Einstein manifold, equivalence principle, geodesic motion, gravity, gravitoelectromagnetism, inertial frame of reference, invariance, Lorentzian manifold, Lorentz transformation, mass–energy equivalence, metric, Minkowski diagram, Minkowski space, simultaneity, spacetime, speed of light, Frame-dragging, Holographic principle, Gravitational waves, Spatiotemporal resolution, Tensor network, Lorentz scalar, Metric tensor</td>
# </tr>
# <tr>
# 	<td>Particle Physics</td>
# 	<td>Accelerator physics, nuclear physics, nuclear astrophysics, particle astrophysics, particle physics phenomenology</td>
# 	<td>Standard Model, quantum field theory, quantum chromodynamics, electroweak theory, effective field theory, lattice field theory, lattice gauge theory, gauge theory, supersymmetry, Grand Unified Theory, superstring theory, M-theory, antimatter, Ternary fission, fusion, Radioactivity, Radioactive decay, Antimatter</td>
# <tr>
# 	<td>Atomic, molecular, and optical physics</td>
# 	<td>Atomic physics, molecular physics, atomic and molecular astrophysics, chemical physics, optics, photonics</td>
# 	<td>Quantum optics, quantum chemistry, quantum information science, lasers, polarization, Casimir effect, reflection, refraction, diffraction, interference</td>
# </tr>
# <tr>
# 	<td>Condensed matter physics</td>
# 	<td>Solid state physics, high pressure physics, low-temperature physics, nanoscale/mesoscopic physics, polymer physics</td>
# 	<td>BCS theory, Bloch's theorem, Fermi gas, Fermi liquid, many-body theory, Bose–Einstein condensate, superfluid, self-organization, (spontaneous) symmetry breaking, Phase transitions, Supercooling, Nanotechnology, Superconductivity</td>
# </tr>
# <tr>
# 	<td>Astrophysics</td>
# 	<td>Cosmology, Stellar Astronomy, Planetary Science, Physical Cosmology, Galactic Astronomy, Extragalactic Astronomy, Celestial Mechanics, Cosmology, gravitation physics, high-energy astrophysics, planetary astrophysics, plasma physics, space physics, stellar astrophysics</td>
# 	<td>Quantum fluctuation, Big Bang, Lambda-CDM model, cosmic inflation, general relativity, law of universal gravitation, Black holes, cosmic background radiation, cosmic strings, dark energy, dark matter, singularity, supernovae</td>
# </tr>
# <tr>
# 	<td>Interdisciplinary Branches</td>
# 	<td>Robotics, Plasma Physics, Astronomy (Astrodynamics, Astrometry, Astrobiology), Atmospheric Physics, Biophysics (Neurophysics, Quantum Biology), Chemical Physics/Physical Chemistry, Computational Physics, Geophysics, Materials Physics/Science, Mathematical Physics, Medical Physics, Ocean Physics/Physical Oceanography, Quantum Information Science, Philosophy of Physics, Psychophysics, Agrophysics, Space Physics, Econophysics, Environmental Physics, Engineering Physics, Quantum Computing, Sociophysics, Cryophysics/Cryogenics, Vehicle Dynamics</td>
# 	<td>Atmospheric pressure photoionization, Flotation of flexible objects, Mass versus weight, Asymptotic safety in quantum gravity, Covariant formulation of classical electromagnetism, Active and passive transformation, Causality, Quantum mind, Quantum brain dynamics</td>
# </tr>
# <tr>
# 	<td>Misc.</td>
# 	<td>Classical: Pressure physics, Chaos theory, Canonical quantization; Modern: Kinematic chain, Classical/Modern states, Plasma Physics, Transport Phenomena, Annihilation physics, Vacuum state physics, Stochastic process, Electroweak theory, Complex/Dynamical systems; Interdisciplinary: Combustion, Brownian motion, Observable universe, Multiverse, Emergence</td>
# 	<td>Ansatz, First principles, Coherent turbulent structure, Contracted Bianchi identities, Covariance group, Ergodic hypothesis, Euclidean vector, Gravitational contact terms, Hyperuniformity, Lorenz gauge condition, Mean-field theory, Negative frequency, Potentiometric surface, Quasistatic approximation, Relative locality, Relativistic heat conduction, Self-organization, Super Bloch oscillations, Sznajd model, Variable structure system, Free/Point/Virtual particles, Wigner–Weyl transform, Polynomial Wigner–Ville distribution, Wigner quasiprobability distribution, Maxwell–Boltzmann statistics, Bose–Einstein statistics, Vector potential, Vector space, State space, Phase space, Phase (matter), Phase space crystals</td>
# </tr>
#
# </table>
#
#
# __Notes__
# ---
# 1. "If, in some cataclysm, all of scientific knowledge were to be destroyed, and only one sentence passed on to the next generations ..., what statement would contain the most information in the fewest words? I believe it is [...] that _all things are made up of atoms – little particles that move around in perpetual motion, attracting each other when they are a little distance apart, but repelling upon being squeezed into one another. ..._" - Richard Feynman
# 4. "Physical science is that department of knowledge which relates to the order of nature, or, in other words, to the regular succession of events.", "Physical science is that department of knowledge which relates to the order of nature, or, in other words, to the regular succession of events." - J. C. Maxwell
# 5. "Physics is an _experimental_ science. Physicists observe the phenomena of nature and try to find patterns and principles that relate these phenomena. These patterns are called physical theories or, when they are very well established and of broad use, physical laws or principles." - Young & Freedman
#
# __References__
# ---
# 1. Feynman, R.P.; Leighton, R.B.; Sands, M. (1963). _The Feynman Lectures on Physics_. Vol. 1. ISBN 978-0-201-02116-5.
# 2. Maxwell, J.C. (1878). _Matter and Motion_. D. Van Nostrand. ISBN 978-0-486-66895-6. "matter and motion."
# 3. Perot, Pierre (1998). _A to Z of Thermodynamics_. Oxford University Press. ISBN 978-0-19-856552-9.
# 6. Van Ness, H.C. (1969). _Understanding Thermodynamics_. Dover Publications, Inc. ISBN 978-0-486-63277-3.
# 7. Dugdale, J. S. (1998). _Entropy and its Physical Meaning_. Taylor and Francis. ISBN 978-0-7484-0569-5.
# 8. Landau and Lifshitz (1951, 1962), _The Classical Theory of Fields_, Library of Congress Card Number 62-9181, Chapters 1–4 (3rd edition is ISBN 0-08-016019-0)
# 9. Edmund Taylor Whittaker (1904). _A Treatise on the Analytical Dynamics of Particles and Rigid Bodies_. Cambridge University Press. ISBN 978-0-521-35883-5.
# 10. Joseph Stiles Beggs (1983). _Kinematics_. Taylor & Francis. p. 1. ISBN 978-0-89116-355-8.
# 11. Thomas Wallace Wright (1896). _Elements of Mechanics Including Kinematics, Kinetics and Statics_. E and FN Spon. Chapter 1.
# 12. Corson and Lorrain, _Electromagnetic Fields and Waves_ ISBN 0-7167-1823-5
#
# __External Links__
# ---
# - AIP.org is the website of the American Institute of Physics
# - IOP.org is the website of the Institute of Physics
# - APS.org is the website of the American Physical Society
# - SPS National is the website of the American Society of Physics Students
# - CAP.ca is the website of the Canadian Association of Physicists
# - EPS.org is the website of the European Physical Society
# - Meta Institute for Computational Physics - Popular Talks
# - ScienceMathMastery - Compilation of YouTube Physics Courses
# - Physics | Channel | MIT Video
# - How to become a GOOD Theoretical Physicist, a website with outline of theoretical physics by Gerard 't Hooft
# - Resource recommendations - List of freely available physics books - Physics Stack Exchange
