# %% [markdown]
# # Outline $\circ$ Branches $\circ$ Concepts $\circ$ Topics $\circ$ Physics (x)

# %% [markdown]
# __Physics__ – natural science that involves the study of matter and its motion through spacetime, along with related concepts such as energy and force. More broadly, it is the general analysis of nature, conducted in order to understand how the universe behaves. a scientific discipline that seeks to construct and experimentally test theories of the physical universe. The solution of tractable problems in nature.
#
# __Universe__ - everything that physically exists: the entirety of space and time, all forms of matter, energy and momentum, and the physical laws and constants that govern them. However, the term 'universe' may also be used in slightly different contextual senses, denoting concepts such as the cosmos or the philosophical world.

# %% [markdown]
# #### ["You just gotta tighten up the bolts a little bit" - Sips](https://youtu.be/9653yNP0pYk?t=6740)

# %% [markdown]
# #### Original HyperPhysics Network Diagrams

# %%
from IPython.display import Image, SVG
# import ipywidgets as widgets

# widgets.ToggleButtons(
#     options=[r'\(1 \star\)', '2 Stars', '3 Stars', '****', '5 Stars'],
#     description='Score:',
#     disabled=False,
#     button_style='primary', # 'success', 'info', 'warning', 'danger' or ''
#     tooltips=[r'\(\star\)', 'Description of regular', 'Description of fast'],
# #     icons=['check'] * 3
# )

# score_slider = widgets.IntSlider(
#     value=3,
#     min=0,
#     max=5,
#     step=1,
#     description='Score: ',
#     disabled=False,
#     continuous_update=False,
#     orientation='horizontal',
#     readout=True,
#     readout_format='d'
# )

# widgets.HBox([score_slider, widgets.Label(value=r"\(\star's\)")])
# Out:
# HBox(children=(IntSlider(value=3, continuous_update=False, description='Score: ', max=5), Label(value="\\(\\st…

# %%
# Source: 'http://hyperphysics.phy-astr.gsu.edu/hbase/'
original_graph_hyperphysics = Image('./Photos/HyperPhysics/Hyperphysics.gif')
original_graph_electromagnetism = Image('./Photos/HyperPhysics/Electromagnetism/Electromagnetism.gif')
original_graph_optics = Image('./Photos/HyperPhysics/Optics/Optics.gif')
original_graph_mechanics = Image('./Photos/HyperPhysics/Mechanics/Mechanics.gif')
original_graph_acoustics = Image('./Photos/HyperPhysics/Acoustics/Acoustics.gif')
original_graph_thermodynamics = Image('./Photos/HyperPhysics/Thermodynamics/Thermodynamics.gif')
original_graph_relativity = Image('./Photos/HyperPhysics/Relativity/Relativity.gif')
original_graph_condensed_matter = Image('./Photos/HyperPhysics/CondensedMatter/CondensedMatter.gif')
original_graph_astrophysics = Image('./Photos/HyperPhysics/Astrophysics/Astrophysics.png')
original_graph_nuclear = Image('./Photos/HyperPhysics/Nuclear/Nuclear.png')
original_graph_quantum = Image('./Photos/HyperPhysics/Quantum/QuantumPhysics.gif')

# %% [markdown]
# #### Recreations Using ```mermaid```

# %%
mermaid_graph_hyperphysics = Image('./Photos/Mermaid/Physics/HyperPhysics.png')
mermaid_graph_electromagnetism = Image('./Photos/Mermaid/Physics/Electromagnetism.png')
mermaid_graph_optics = Image('./Photos/Mermaid/Physics/Optics.png')
mermaid_graph_mechanics = Image('./Photos/Mermaid/Physics/Mechanics.png')
mermaid_graph_acoustics = Image('./Photos/Mermaid/Physics/Acoustics.png')
mermaid_graph_thermodynamics = Image('./Photos/Mermaid/Physics/Thermodynamics.png')
mermaid_graph_relativity = Image('./Photos/Mermaid/Physics/Relativity.png')
mermaid_graph_condensed_matter = Image('./Photos/Mermaid/Physics/CondensedMatter.png')
mermaid_graph_astrophysics = Image('./Photos/Mermaid/Physics/Astrophysics.png')
mermaid_graph_nuclear = Image('./Photos/Mermaid/Physics/Nuclear.png')
mermaid_graph_quantum = Image('./Photos/Mermaid/Physics/QuantumPhysics.png')

# %% [markdown]
# #### Rating-Color Scale

# %%
default_colors = ('silver', 'tomato', 'gold', 'yellowgreen', 'skyblue', 'orchid')
rate = ('silver', 'red', 'orange', 'yellow', 'green', 'blue')  # 
polys = [polygon([(0,0), (0,1), (1,1), (1,0)], axes=False, color=c) + text(f'{i +1} Star' + ('s' if i else ''), (1/2, 1/2), color='black') for i, c in enumerate(rate[1:])]
graphics_array(polys)
# Out:
# Graphics Array of size 1 x 5

# %%
class CategoryLabel:
    def __init__(self, label, score=0, color=None, color_pallete=default_colors):
        self.label = label
        self.score = score
        self._color = color
        self.color_pallete = color_pallete
    
    @property
    def color(self):
        if self._color is None:
            self._color = self.color_pallete[self.score]
        return self._color

# %%
aberration_of_starlight          = CategoryLabel('Aberration \nof \nStarlight',          )
absorption                       = CategoryLabel('Absorption',                           )
acoustics                        = CategoryLabel('Acoustics',                            )
ac_circuits                      = CategoryLabel('AC \nCircuits',                        )
adiabatic                        = CategoryLabel('Adiabatic',                            )
advance_of_perihelion_of_mercury = CategoryLabel('Advance of \nPerihelion \nof Mercury', )
air_columns                      = CategoryLabel('Air Columns',                          )
alpha                            = CategoryLabel('Alpha',                                )
amperes_law                      = CategoryLabel("Ampere's \nLaw",                       )
aperture                         = CategoryLabel('Aperture',                             )
applications                     = CategoryLabel('Applications',                         )
astrophysics                     = CategoryLabel('Astrophysics',                         )
atmospheric_phenomena            = CategoryLabel('Atmospheric \nPhenomena',              )
atomic_properties                = CategoryLabel('Atomic \nProperties',                  )
auditorium_acoustics             = CategoryLabel('Auditorium \nAcoustics',               )

# %%
show(advance_of_perihelion_of_mercury.label)
# Out:
# 'Advance of \nPerihelion \nof Mercury'

# %% [markdown]
# ##### Hard-Coding Labels

# %%
# A
(
    aberration_of_starlight,
    absorption,
    acoustics,
    ac_circuits,
    adiabatic,
    advance_of_perihelion_of_mercury,
    air_columns,
    alpha,
    amperes_law,
    aperture,
    applications,
    astrophysics,
    atmospheric_phenomena,
    atomic_properties,
    auditorium_acoustics,
    ) = (
        'Aberration \nof \nStarlight',
        'Absorption',
        'Acoustics',
        'AC \nCircuits',
        'Adiabatic',
        'Advance of \nPerihelion \nof Mercury',
        'Air Columns',
        'Alpha',
        "Ampere's \nLaw",
        'Aperture',
        'Applications',
        'Astrophysics',
        'Atmospheric \nPhenomena',
        'Atomic \nProperties',
        'Auditorium \nAcoustics',
        )
# B
(
    band_theory_of_solids,
    beta,
    beats,
    bioelectrity,
    biot_savart_law,
    blackbody_radiation,
    black_hole,
    black_holes,
    bl_lacertae_objects,
    bohr_theory,
    boltzmann_distribution,
    ) = (
        'Band Theory \nof Solids',
        'Beta',
        'Beats',
        'Bioelectrity',
        'Biot-Savart \nLaw',
        'Blackbody \nRadiation',
        'Black \nHole',
        'Black \nHoles',
        'BL \nLacertae \nObjects',
        'Bohr \nTheory',
        'Boltzmann \nDistribution',
        )
# C
(
    contraction,
    color,
    color_vision,
    circular_motion,
    circuit_elements,
    condensed_matter,
    capacitor,
    coulombs_law,
    current_law,
    conservation_laws,
    conservation_of_energy,
    constant_volume,
    conservation_of_momentum,
    conservation_of_angular_momentum,
    compton_scattering,
    conduction,
    convection,
    crystal_lattice,
    celestial_measurement,
    cosmology,
    ) = (
        'Contraction',
        'Color',
        'Color \nVision',
        'Circular \nMotion',
        'Circuit \nElements',
        'Condensed \nMatter',
        'Capacitor',
        "Coulomb's \nLaw",
        'Current \nLaw',
        'Conservation \nLaws',
        'Conservation \nof \nEnergy',
        'Constant \nVolume',
        'Conservation \nof \nMomentum',
        'Conservation of \nAngular \nMomentum',
        'Compton \nScattering',
        'Conduction',
        'Convection',
        'Crystal \nLattice',
        'Celestial \nMeasurement',
        'Cosmology',
        )
# D
(
    decay_paths,   
    density_parameter, 
    distance_measurement,
    dc_circuits,
    diamagnetism,
    dielectric_media,
    double_slit,
    diffraction,
    decibels,
    doppler_shift,
    dba,
    doppler_effect,
    ) = (
        'Decay \nPaths',   
        'Density \nParameter', 
        'Distance \nMeasurement',
        'DC \nCircuits',
        'Diamagnetism',
        'Dielectric \nMedia',
        'Double \nSlit',
        'Diffraction',
        'Decibels',
        'Doppler \nShift',
        'dBA',
        'Doppler \nEffect',
        )

# E
(
    emc2,
    experiments_of_general_relativity,
    experiments_of_special_relativity,
    einstein_velocity_addition,
    equal_tempered,
    equilibrium,
    electric_circuits,
    electric_charge,
    electric_current,
    electric_field,
    electric_power,
    electromagnetism,
    electronics,
    em_waves,
    emf,
    electrical_properties,
    expanding_universe,
    electron_density,
    entropy,
    enthalpy,
    equipartition_of_energy,
    ) = (
        'E=mc^2',
        'Experiments of \nGeneral Relativity',
        'Experiments of \nSpecial Relativity',
        'Einstein \nVelocity \nAddition',
        'Equal \nTempered',
        'Equilibrium',
        'Electric \nCircuits',
        'Electric \nCharge',
        'Electric \nCurrent',
        'Electric \nField',
        'Electric \nPower',
        'Electromagnetism',
        'Electronics',
        'EM \nWaves',
        'EMF',
        'Electrical \nProperties',
        'Expanding \nUniverse',
        'Electron \nDensity',
        'Entropy',
        'Enthalpy',
        'Equipartition \nof Energy',
        )

# F
(
    first_law_of_thermodynamics,
    fermi_energy,
    ferromagnetism,
    failures_of_classical_physics,
    fast_breeder,
    fusion_reactors,
    fluid_mechanics,
    fabry_perot_interferometer,
    fraunhofer,
    fourier_optics,
    fiber_optics,
    fresnel,
    faradays_law,
    forces,
    ) = (
        'First Law of \nThermodynamics',
        'Fermi \nEnergy',
        'Ferromagnetism',
        'Failures of \nClassical Physics',
        'Fast \nBreeder',
        'Fusion \nReactors',
        'Fluid \nMechanics',
        'Fabry-Perot \nInterferometer',
        'Fraunhofer',
        'Fourier \nOptics',
        'Fiber \nOptics',
        'Fresnel',
        "Faraday's \nLaw",
        'Forces',
        )
# G
(
    gravity,
    gamma,
    galilean_transformation, 
    gravitational_contraction,
    gravitational_time_dilation,
    gravitational_waves, 
    grating,
    gausss_law
    ) = (
        'Gravity',
        'Gamma',
        'Galilean \nTransformation',
        'Gravitational \nContraction',
        'Gravitational \nTime \nDilation',
        'Gravitational \nWaves',
        'Grating',
        "Gauss's \nLaw",
        )
# H
(
    hearing,
    hydrogen_energies,
    hydrogen_spectrum,
    heat,
    heat_engines,
    heat_transfer,
    holography,
    hyperphysics,
    household_wiring,
    half_life,
    h_he_abundance,
    ) = (
        'Hearing',
        'Hydrogen \nEnergies',
        'Hydrogen \nSpectrum',
        'Heat',
        'Heat \nEngines',
        'Heat \nTransfer',
        'Holography',
        'HyperPhysics',
        'Household \nWiring',
        'Half \nLife',
        'H-He \nAbundance',
        )
# I
(
    inductor,
    inverse_square_law,
    interference,
    isotopes,
    ideas_of_special_relativity,
    ideas_of_general_relativity,
    internal_energy,
    isothermal,
    ideal_gas_law,
    interference_filters,
    index_of_refraction,
    ) = (
        'Inductor',
        'Inverse \nSquare \nLaw',
        'Interference',
        'Isotopes',
        'Ideas of \nSpecial \nRelativity',
        'Ideas of \nGeneral \nRelativity',
        'Internal \nEnergy',
        'Isothermal',
        'Ideal \nGas \nLaw',
        'Interference \nFilters',
        'Index of \nRefraction',
        )
# K
kinetic_theory,         = 'Kinetic \nTheory',  
# L
(
    lorentz_transformation,
    lattice_vibrations,
    lorentz_force_law,
    light_water_reactions,
    loudness,
    lasers,
    lenses,
    light_intensity,
    light_propagation,
    length_contraction,
    ) = (
        'Lorentz \nTransformation',
        'Lattice \nVibrations',
        "Lorentz' \nForce \nLaw",
        'Light \nWater \nReactions',
        'Loudness',
        'Lasers',
        'Lenses',
        'Light \nIntensity',
        'Light \nPropagation',
        'Length \nContraction',
        )
# M
(
    michelson_morley_experiment,
    musical_instruments,
    musical_scales,
    muon_experiment,
    main_sequence,
    milky_way_galaxy,
    mechanics,
    metals,
    magnetic_properties,
    mirrors,
    mirror_instruments,
    michelson_interferometer,
    magnetic_field,
    maxwells_equations,
    measurement,
    mass,
    ) = (
        'Michelson-Morley \nExperiment',
        'Musical \nInstruments',
        'Musical \nScales',
        'Muon \nExperiment',
        'Main \nSequence',
        'Milky \nWay \nGalaxy',
        'Mechanics',
        'Metals',
        'Magnetic \nProperties', 
        'Mirrors',
        'Mirror \nInstruments',
        'Michelson \nInterferometer',
        'Magnetic \nField',
        "Maxwell's \nEquations",
        'Measurement',
        'Mass',
        )
# N
(
    nuclear,
    nuclear_particles,
    nuclear_structure,
    nuclear_reactions,
    nuclear_energy,
    nuclear_medicine,
    nuclear_notation,
    nuclear_forces,
    nuclear_binding_energy,
    nuclear_fission,
    nuclear_fusion,
    nuclear_size,
    nuclear_spectra,
    nuclear_scale_model,
    nuclear_units,
    nova,
    nuclear_weapons,
    neutron_star,
    nuclear_binding_energy,
    newtons_laws,
    ) = (
        'Nuclear',
        'Nuclear \nParticles',
        'Nuclear \nStructure',
        'Nuclear \nReactions',
        'Nuclear \nEnergy',
        'Nuclear \nMedicine',
        'Nuclear \nNotation',
        'Nuclear \nForces',
        'Nuclear \nBinding Energy',
        'Nuclear \nFission',
        'Nuclear \nFusion',
        'Nuclear \nSize',
        'Nuclear \nSpectra',
        'Nuclear \nScale \nModel',
        'Nuclear \nUnits',
        'Nova',
        'Nuclear \nWeapons',
        'Neutron Star',
        'Nuclear \nBinding \nEnergy',
        "Newton's \nLaws",
        )
# O
(
    orbits,
    other_galaxies,
    optics,
    ohms_law,
    optical_instruments
    ) = (
        'Orbits',
        'Other \nGalaxies',
        'Optics',
        "Ohm's \nLaw",
        'Optical \nInstruments',
        )
# P
(
    pre_nova,
    post_nova,
    pulsar,
    planck_hypothesis,
    photoelectric_effect,
    particles,
    particle_physics,
    piezoelectric_effect,
    paramagnetism,
    periodic_table,
    pv_diagrams,
    phase_changes,
    photometry,
    prisms,
    polarization,
    periodic_motion,
    phons,
    pitch,
    pythagorean,
    physical_units,
    principle_of_equivalence
    ) = (
        'Pre-Nova',
        'Post-Nova',
        'Pulsar',
        'Planck \nHypothesis',
        'Photoelectric \nEffect',
        'Particles',
        'Particle \nPhysics',
        'Piezoelectric \nEffect',
        'Paramagnetism',
        'Periodic \nTable',
        'PV \nDiagrams',
        'Phase \nChanges',
        'Photometry',
        'Prisms',
        'Polarization',
        'Periodic \nMotion',
        'Phons',
        'Pitch',
        'Pythagorean',
        'Physical \nUnits',
        'Principle \nof \nEquivalence',
        )
# Q
(
    quantum_properties,
    quantum,
    quantum_numbers,
    quantum_statistics,
    quasars
    ) = (
        'Quantum \nProperties',
        'Quantum',
        'Quantum \nNumbers',
        'Quantum \nStatistics',
        'Quasars',
        )
# R
(
    red_giant_post_nova,
    radiation,
    relative_humidity,
    red_giant,
    red_giant_pre_nova,
    red_supergiant,
    radiation_risk,
    radiation_curves,
    radioactivity,
    radioactive_dating,
    radiation_detection,
    rutherford_scattering,
    resistor,
    refraction,
    reflection, 
    rotation,
    resonance,
    relativistic_mechanical_quantities,
    relativity,
    reverberation,
    relativistic_mass
    ) = (
        'Red Giant \n(Post-Nova)',
        'Radiation',
        'Relative \nHumidity',
        'Red \nGiant',
        'Red Giant \n(Pre-Nova)',
        'Red \nSupergiant',
        'Radiation \nRisk',
        'Radiation \nCurves',
        'Radioactivity',
        'Radioactive \nDating',
        'Radiation \nDetection',
        'Rutherford \nScattering',
        'Resistor',
        'Refraction',
        'Reflection',
        'Rotation',
        'Resonance',
        'Relativistic \nMechanical \nQuantities',
        'Relativity',
        'Reverberation',
        'Relativistic \nMass',
        )
# S
(
    snells_law,
    single_slit,
    scattering,
    sound_propagation,
    sound_reproduction,
    standing_waves,
    strings,
    solar_system,
    seyfert_galaxies,
    sound_measurement,
    supernova,
    stars,
    semiconductor_properties,
    schrodinger_equation,
    solid_mechanics,
    superconductivity,
    solid_state_electronics,
    specific_heat,
    second_law_of_thermodynamics,
    system_work
    ) = (
        "Snell's \nLaw",
        'Single \nSlit',
        'Scattering',
        'Sound \nPropagation',
        'Sound \nReproduction',
        'Standing Waves',
        'Strings',
        'Solar \nSystem',
        'Seyfert Galaxies',
        'Sound \nMeasurement',
        'Supernova',
        'Stars',
        'Semiconductor \nProperties',
        'Schrodinger \nEquation',
        'Solid \nMechanics',
        'Superconductivity',
        'Solid \nState \nElectronics',
        'Specific \nHeat',
        'Second Law of \nThermodynamics',
        'System \nWork',
        )
# T
(
    temperature_scales,
    thermal_expansion,
    thermal_equilibrium,
    threek_background_radiation,
    temperature,
    thin_film,
    thermodynamics,
    traveling_waves,
    timbre,
    torques,
    time_dilation,
    twin_paradox
    ) = (
        'Temperature \nScales',
        'Thermal \nExpansion',
        'Thermal \nEquilibrium',
        '3K \nBackground \nRadiation',
        'Temperature',
        'Thin \nFilm',
        'Thermodynamics',
        'Traveling \nWaves',
        'Timbre',
        'Torques',
        'Time \nDilation',
        'Twin \nParadox',
        )
# U
uncertainty_principle = 'Uncertainty \nPrinciple'
# V
(
    voltage_law,
    vision,
    voltage,
    vector_operations,
    velocity_acceleration
    ) = (
        'Voltage \nLaw',
        'Vision',
        'Voltage',
        'Vector \nOperations',
        'Velocity & \nAcceleration',
        )
# W
(
    weinbergs_first_three_minutes,
    work_energy_power,
    work_energy_principle,
    wavefunction,
    wien_displacement_law,
    wave_particle_duality,
    white_dwarf) = (
        "Weinberg's First \nThree Minutes",
        'Work, \nEnergy, \n& Power',
        'Work-Energy \nPrinciple', 
        'Wavefunction',
        'Wien \nDisplacement \nLaw',
        'Wave-Particle \nDuality',
        'White \nDwarf',
        )
# Z
zeroth_law_of_thermodynamics = 'Zeroth Law of \nThermodynamics'

# %%
params_default = {
    'figsize': (16, 16),
    'vertex_size': 2000,
    'layout': 'spring',
}
params_interactive = {
    'method': 'js',
    'vertex_size': 25,
    'link_distance': 150,
    'charge':-500,
    'force_spring_layout': True,
}

# %%
dict_hyperphysics = {
    hyperphysics: [mechanics, electromagnetism, optics, acoustics, relativity, astrophysics, quantum, nuclear, condensed_matter, thermodynamics],
}
dict_mechanics = {
    mechanics: [conservation_laws, velocity_acceleration, circular_motion, solid_mechanics, physical_units],
    physical_units: [vector_operations,],
    solid_mechanics: [fluid_mechanics,],
    velocity_acceleration: [periodic_motion, newtons_laws],
    newtons_laws: [mass, forces, work_energy_power],
    forces: [gravity,],
    conservation_laws: [conservation_of_momentum, conservation_of_angular_momentum, conservation_of_energy],
    conservation_of_energy: [work_energy_principle, ],
    work_energy_power: [conservation_of_energy, work_energy_principle],  
    circular_motion: [orbits, ],
    orbits: [rotation, ],
    rotation: [conservation_of_angular_momentum, torques],
    torques: [conservation_of_angular_momentum, equilibrium],
}
dict_electromagnetism = {
    electromagnetism: [applications, electric_circuits, circuit_elements, electric_charge, magnetic_field, lorentz_force_law, electronics, bioelectrity],
    electric_circuits: [voltage_law, dc_circuits],
    circuit_elements: [resistor, capacitor, inductor],
    electric_charge: [coulombs_law, ],    
    voltage_law: [current_law, ],
    dc_circuits: [ohms_law, electric_power, ac_circuits, ohms_law],
    coulombs_law: [gausss_law, electric_field],
    amperes_law: [biot_savart_law, magnetic_field],
    maxwells_equations: [em_waves, lorentz_force_law],
    current_law: [ohms_law, ],
    ac_circuits: [household_wiring, ohms_law],
    biot_savart_law: [faradays_law, ],
    electric_field: [voltage, gausss_law],
    voltage: [emf, measurement, electric_current],
    electric_current: [measurement, ],
    }
dict_optics = {
    optics: [color, light_intensity, atmospheric_phenomena, light_propagation, quantum_properties, polarization],
    color: [color_vision,],
    light_intensity: [photometry,],
    light_propagation: [refraction, interference, diffraction, reflection],
    polarization: [scattering,],
    refraction: [lenses, snells_law],
    reflection: [mirrors,],
    diffraction: [fraunhofer,],
    lasers: [quantum_properties, holography],
    snells_law: [index_of_refraction,],
    thin_film: [interference, double_slit,],
    holography: [fourier_optics,],
    prisms: [lenses, optical_instruments],
    mirror_instruments: [mirrors, fiber_optics],
    double_slit: [michelson_interferometer,],
    fresnel: [fraunhofer, single_slit,],
    optical_instruments: [vision,],
    fiber_optics: [absorption,],
    single_slit: [aperture,],
    fabry_perot_interferometer: [michelson_interferometer, interference_filters],
    aperture: [grating,],
}
dict_acoustics = {
    acoustics: [hearing, sound_measurement, periodic_motion, sound_propagation, resonance, musical_instruments],
	auditorium_acoustics: [inverse_square_law,],
	air_columns: [standing_waves, musical_scales],
	decibels: [phons,],
	diffraction: [sound_reproduction,],
	reflection: [interference,],
	refraction: [diffraction,],
	interference: [beats, refraction],
	sound_propagation: [reflection, auditorium_acoustics],
	sound_measurement: [decibels,],
	strings: [standing_waves, air_columns],
	pitch: [loudness,],
	phons: [dba,],
	periodic_motion: [traveling_waves,],
	pythagorean: [equal_tempered,],
    hearing: [pitch,],
	loudness: [timbre,],
	musical_instruments: [strings,],
	musical_scales: [pythagorean,],
    traveling_waves: [doppler_effect,],
	inverse_square_law: [reverberation,],
	resonance: [standing_waves,],
}
dict_relativity = {
    relativity: [ideas_of_special_relativity, experiments_of_special_relativity, doppler_shift, ideas_of_general_relativity, experiments_of_general_relativity, relativistic_mechanical_quantities],
    relativistic_mass: [emc2, time_dilation],
    lorentz_transformation: [length_contraction, time_dilation],
    galilean_transformation: [lorentz_transformation, ideas_of_special_relativity],
    michelson_morley_experiment: [aberration_of_starlight, experiments_of_special_relativity],
    muon_experiment: [relativistic_mass, aberration_of_starlight],
    twin_paradox: [einstein_velocity_addition, doppler_shift],
    einstein_velocity_addition: [nuclear_binding_energy,],
    principle_of_equivalence: [advance_of_perihelion_of_mercury, ideas_of_general_relativity],
    advance_of_perihelion_of_mercury: [gravitational_time_dilation,],
    gravitational_time_dilation: [black_holes,],
    experiments_of_general_relativity: [gravitational_waves,],
}
dict_astrophysics = {
    astrophysics: [solar_system, cosmology, other_galaxies, milky_way_galaxy],
    contraction: [black_hole, neutron_star],
    cosmology: [weinbergs_first_three_minutes, expanding_universe],
    expanding_universe: [density_parameter, threek_background_radiation, distance_measurement],
    other_galaxies: [seyfert_galaxies, bl_lacertae_objects, quasars],
    supernova: [black_hole, neutron_star],
    milky_way_galaxy: [stars, gravitational_contraction],
    main_sequence: [red_supergiant, red_giant],
    red_supergiant: [supernova, contraction],
    red_giant: [red_giant_pre_nova, white_dwarf],
    nova: [red_giant_post_nova, white_dwarf],
    pre_nova: [nova,],
    post_nova: [pre_nova,],
    threek_background_radiation: [h_he_abundance,],
    stars: [celestial_measurement,],
    seyfert_galaxies: [distance_measurement,],
    bl_lacertae_objects: [distance_measurement,],
    quasars: [distance_measurement,],
    gravitational_contraction: [main_sequence,],
    neutron_star: [pulsar,],
    }
dict_quantum = {
    quantum: [failures_of_classical_physics, photoelectric_effect, bohr_theory, wavefunction], 
    quantum_numbers: [hydrogen_energies,], 
    failures_of_classical_physics: [planck_hypothesis, wave_particle_duality], 
    photoelectric_effect: [compton_scattering, blackbody_radiation], 
    hydrogen_energies: [hydrogen_spectrum, atomic_properties], 
    schrodinger_equation: [hydrogen_energies, particles, forces],
    atomic_properties: [periodic_table,],
    blackbody_radiation: [radiation_curves,],
    bohr_theory: [quantum_numbers,],
    planck_hypothesis: [uncertainty_principle,],
    radiation_curves: [wien_displacement_law,],
    uncertainty_principle: [quantum_statistics,],
    wavefunction: [schrodinger_equation,],
    wave_particle_duality: [uncertainty_principle,],
    wien_displacement_law: [threek_background_radiation,],
    }
dict_nuclear = {
    nuclear: [nuclear_particles, radioactivity, nuclear_structure, nuclear_reactions, nuclear_energy, nuclear_medicine],
    nuclear_particles: [nuclear_notation,],
    nuclear_notation: [isotopes, nuclear_forces],
    nuclear_reactions: [nuclear_binding_energy,],
    nuclear_binding_energy: [nuclear_fission,],
    nuclear_fission: [nuclear_fusion,],
    nuclear_forces: [nuclear_size,],
    nuclear_structure: [nuclear_spectra,],
    nuclear_spectra: [particle_physics,],
    nuclear_size: [nuclear_scale_model,],
    nuclear_scale_model: [nuclear_units,],
    nuclear_energy: [nuclear_weapons, light_water_reactions],
    rutherford_scattering: [nuclear_forces, nuclear_size, nuclear_scale_model],
    radioactivity: [half_life, alpha, beta, gamma, decay_paths],
    half_life: [radiation_risk,],
    decay_paths: [radioactive_dating,],
    radioactive_dating: [radiation_detection,],
    light_water_reactions: [fast_breeder,],
    fast_breeder: [fusion_reactors,],
    }
dict_condensed_matter = {
    condensed_matter: [semiconductor_properties, crystal_lattice, metals, electrical_properties, magnetic_properties],
    magnetic_properties: [ferromagnetism, paramagnetism, diamagnetism],
    electrical_properties: [superconductivity, band_theory_of_solids],
    band_theory_of_solids: [dielectric_media, piezoelectric_effect],
    semiconductor_properties: [solid_state_electronics,],
    lattice_vibrations: [crystal_lattice, specific_heat],
    metals: [fermi_energy,],
    fermi_energy: [electron_density,],
}
dict_thermodynamics = {
    thermodynamics: [internal_energy, temperature, specific_heat, heat_transfer, heat_engines, kinetic_theory],
    temperature: [temperature_scales,],
    temperature_scales: [thermal_expansion,],
    thermal_equilibrium: [zeroth_law_of_thermodynamics,],
    ideal_gas_law: [equipartition_of_energy,],
    internal_energy: [heat,],
    isothermal: [adiabatic,],
    heat: [system_work,],
    heat_engines: [second_law_of_thermodynamics, isothermal],
    heat_transfer: [conduction, convection, radiation],
    second_law_of_thermodynamics: [entropy,],
    system_work: [first_law_of_thermodynamics,],
    specific_heat: [enthalpy,],
    adiabatic: [constant_volume,],
    constant_volume: [pv_diagrams,],
    enthalpy: [phase_changes,],
    equipartition_of_energy: [boltzmann_distribution,],
    phase_changes: [thermal_equilibrium,],
    radiation: [relative_humidity,],
    kinetic_theory: [ideal_gas_law,],
}

# %% [markdown]
# #### Create Individual Graphs

# %%
graph_hyperphysics = Graph(dict_hyperphysics)
graph_mechanics = Graph(dict_mechanics)
graph_electromagnetism = Graph(dict_electromagnetism)
graph_optics = Graph(dict_optics)
graph_acoustics = Graph(dict_acoustics)
graph_relativity = Graph(dict_relativity)
graph_astrophysics = Graph(dict_astrophysics)
graph_quantum = Graph(dict_quantum)
graph_nuclear = Graph(dict_nuclear)
graph_condensed_matter = Graph(dict_condensed_matter)
graph_thermodynamics = Graph(dict_thermodynamics)

# %% [markdown]
# #### Rating Assignments

# %%
ratings_hyperphysics = {
    rate[0]: [hyperphysics, ],
    rate[1]: [acoustics, ],
    rate[2]: [condensed_matter, optics],
    rate[3]: [nuclear, electromagnetism],
    rate[4]: [relativity, quantum, thermodynamics],
    rate[5]: [mechanics, astrophysics]
    }
ratings_mechanics = {
    rate[1]: [physical_units, vector_operations, ],
    rate[2]: [work_energy_power, velocity_acceleration, mass, torques, ],
    rate[3]: [fluid_mechanics, solid_mechanics, work_energy_principle, orbits, rotation, ],
    rate[4]: [conservation_of_momentum, conservation_of_angular_momentum, conservation_of_energy, periodic_motion, circular_motion, ],
    rate[5]: [forces, newtons_laws, gravity, conservation_laws,equilibrium, mechanics, ]
    }
ratings_electromagnetism = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_optics = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_acoustics = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_relativity = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_astrophysics = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_quantum = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_nuclear = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_condensed_matter = {
    rate[1]: [],
    rate[2]: [],
    rate[3]: [],
    rate[4]: [],
    rate[5]: []
    }
ratings_thermodynamics = {
    rate[1]: [heat_engines,temperature_scales],
    rate[2]: [relative_humidity, isothermal, adiabatic, enthalpy, specific_heat],
    rate[3]: [internal_energy, heat, system_work, first_law_of_thermodynamics, temperature, constant_volume, thermal_expansion, kinetic_theory, ideal_gas_law, pv_diagrams],
    rate[4]: [heat_transfer, conduction, convection, radiation, thermal_equilibrium, zeroth_law_of_thermodynamics, thermodynamics],   
    rate[5]: [second_law_of_thermodynamics, entropy, equipartition_of_energy, boltzmann_distribution, phase_changes]
    }

# %%
graph_hyperphysics.show(vertex_colors=ratings_hyperphysics, **params_default)
# Out:
# Graphics object consisting of 22 graphics primitives

# %%
graph_mechanics.show(vertex_colors=ratings_mechanics, **params_default)
# Out:
# Graphics object consisting of 48 graphics primitives

# %%
graph_electromagnetism.show(vertex_colors=ratings_electromagnetism, **params_default)
# Out:
# Graphics object consisting of 67 graphics primitives

# %%
graph_optics.show(vertex_colors=ratings_optics, **params_default)
# Out:
# Graphics object consisting of 74 graphics primitives

# %%
graph_acoustics.show(vertex_colors=ratings_acoustics, **params_default)
# Out:
# Graphics object consisting of 62 graphics primitives

# %%
graph_relativity.show(vertex_colors=ratings_relativity, **params_default)
# Out:
# Graphics object consisting of 50 graphics primitives

# %%
graph_astrophysics.show(vertex_colors=ratings_astrophysics, **params_default)
# Out:
# Graphics object consisting of 67 graphics primitives

# %%
graph_quantum.show(vertex_colors=ratings_quantum, **params_default)
# Out:
# Graphics object consisting of 47 graphics primitives

# %%
graph_nuclear.show(vertex_colors=ratings_nuclear, **params_default)
# Out:
# Graphics object consisting of 64 graphics primitives

# %%
graph_condensed_matter.show(vertex_colors=ratings_condensed_matter, **params_default)
# Out:
# Graphics object consisting of 36 graphics primitives

# %%
graph_thermodynamics.show(vertex_colors=ratings_thermodynamics, **params_default)
# Out:
# Graphics object consisting of 58 graphics primitives

# %%
ratings_combined = ratings_hyperphysics | ratings_mechanics | ratings_electromagnetism | ratings_optics | ratings_acoustics | ratings_relativity | ratings_astrophysics | ratings_quantum | ratings_nuclear | ratings_condensed_matter | ratings_thermodynamics
params_default['vertex_colors'] = ratings_combined
params_interactive['vertex_colors'] = ratings_combined

# %%
graph_hyperphysics = graph_physics.union(
    graph_mechanics).union(
        graph_electromagnetism).union(
            graph_optics).union(
                graph_acoustics).union(
                    graph_relativity).union(
                        graph_astrophysics).union(
                            graph_quantum).union(
                                graph_nuclear).union(
                                    graph_condensed_matter).union(
                                        graph_thermodynamics)
graph_hyperphysics.show(**params_default)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2443/2041224120.py in <module>
# ----> 1 graph_hyperphysics = graph_physics.union(
#       2     graph_mechanics).union(
#       3         graph_electromagnetism).union(
#       4             graph_optics).union(
#       5                 graph_acoustics).union(
#
# NameError: name 'graph_physics' is not defined

# %%
graph_hyperphysics.show(**params_interactive)

# %% [markdown]
# <table>
# <tr>
#    	<th>Theory</th>
#    	<th>Topic</th>
# 	<th>Concept</th>
# </tr>
# <tr>
# 	<td rowspan="7">Mechanics</td>
# 	<td>Biomechanics, Aerodynamics, Classical Mechanics, Homeokinetics, Kinematics, Dynamics, Statics, Continuum Mechanics, Celestial Mechanics, chaos theory, acoustics</td>
# 	<td>Galilean invariance, conservation laws, harmonic oscillator, Tait–Bryan angles, Euler angles, Virial theorem, Newton's theorem of revolving orbits</td>
# </tr>
# <tr>
# 	<td rowspan="3">Analytical Mechanics: Noether's theorem, Stationary-action principle, Generalized Lagrangian mean, Legendre transformation</td>
# 	<td>Newtonian Mechanics</td>
# </tr>
# <tr>
# 	<td>Lagrangian Mechanics</td>
# </tr>
# <tr>
# 	<td>Hamiltonian Mechanics</td>
# </tr>
# <tr>
# 	<td rowspan="3">Fluid Mechanics: Navier–Stokes Equations</td>
# 	<td>Fluid Dynamics</td>
# </tr>
# <tr>
# 	<td>Fluid Kinematics</td>
# </tr>
# <tr>
# 	<td>Fluid Statics</td>
# </tr>
# <tr>
# 	<td>Electromagnetism</td>
# 	<td>Electrostatics, electrodynamics, electricity, magnetism, magnetostatics, Maxwell's equations, optics</td>
# 	<td>induction, radiation, Gaussian surface, flux, monopole</td>
# </tr>
# <tr>
# 	<td>Thermodynamics and Statistical Mechanics</td>
# 	<td>Heat engine, kinetic theory, Non-Equilibrium Mechanics</td>
# 	<td>conjugate variables, enthalpy, entropy, equation of state, equipartition theorem, thermodynamic free energy, laws of thermodynamics, Maxwell relations, Ising model, mechanical action, partition function, state function, statistical ensemble, Thermodynamic limit</td>
# </tr>
# <tr>
# 	<td>Quantum Mechanics</td>
# 	<td>Quantum Foundations, Quantum Information Theory, Quantum Field theory, Path integral formulation, scattering theory, Schrödinger Equation, Dirac Equation, Quantum Statistical Mechanics, Quantum Electrodynamics, Quantum Chromodynamics</td>
# 	<td>The Photoelectric Effect, Wave-Particle Duality, Wavefunction, Matrix Mechanics, Uncertainty Principle, Relativistic Quantum Mechanics, Adiabatic approximation, black-body radiation, correspondence principle, free particle, Hamiltonian, Hilbert space, identical particles, observer effect, quantum entanglement, quantum harmonic oscillator, quantum tunneling, Dirac equation, wave mechanics, zero-point energy, Pauli Exclusion Principle, Wave function collapse, Observer (Effect), Path integral formulation, Perturbation theory, Classical limit, Classical probability density, Coherence, Quantum non-equilibrium, Quantum pseudo-telepathy, Quantum gravity, Loop quantum gravity, String theory, QED vacuum, Spin foam, quantum gravity, Theory of Everything, Grand Unified Theory, (Super)Symmetry</td>
# </tr>
# <tr>
# 	<td>Relativity</td>
# 	<td>Special relativity, general relativity, Einstein field equations</td>
# 	<td>Quantum gravity, Covariance, Einstein manifold, equivalence principle, geodesic motion, gravity, gravitoelectromagnetism, inertial frame of reference, invariance, Lorentzian manifold, Lorentz transformation, mass–energy equivalence, metric, Minkowski diagram, Minkowski space, simultaneity, spacetime, speed of light, Frame-dragging, Holographic principle, Gravitational waves, Spatiotemporal resolution, Tensor network, Lorentz scalar, Metric tensor</td>
# </tr>
# <tr>
# 	<td>Particle Physics</td>
# 	<td>Accelerator physics, nuclear physics, nuclear astrophysics, particle astrophysics, particle physics phenomenology</td>
# 	<td>Standard Model, quantum field theory, quantum chromodynamics, electroweak theory, effective field theory, lattice field theory, lattice gauge theory, gauge theory, supersymmetry, Grand Unified Theory, superstring theory, M-theory, antimatter, Ternary fission, fusion, Radioactivity, Radioactive decay, Antimatter</td>
# <tr>
# 	<td>Atomic, molecular, and optical physics</td>
# 	<td>Atomic physics, molecular physics, atomic and molecular astrophysics, chemical physics, optics, photonics</td>
# 	<td>Quantum optics, quantum chemistry, quantum information science, lasers, polarization, Casimir effect, reflection, refraction, diffraction, interference</td>
# </tr>
# <tr>
# 	<td>Condensed matter physics</td>
# 	<td>Solid state physics, high pressure physics, low-temperature physics, nanoscale/mesoscopic physics, polymer physics</td>
# 	<td>BCS theory, Bloch's theorem, Fermi gas, Fermi liquid, many-body theory, Bose–Einstein condensate, superfluid, self-organization, (spontaneous) symmetry breaking, Phase transitions, Supercooling, Nanotechnology, Superconductivity</td>
# </tr>
# <tr>
# 	<td>Astrophysics</td>
# 	<td>Cosmology, Stellar Astronomy, Planetary Science, Physical Cosmology, Galactic Astronomy, Extragalactic Astronomy, Celestial Mechanics, Cosmology, gravitation physics, high-energy astrophysics, planetary astrophysics, plasma physics, space physics, stellar astrophysics</td>
# 	<td>Quantum fluctuation, Big Bang, Lambda-CDM model, cosmic inflation, general relativity, law of universal gravitation, Black holes, cosmic background radiation, cosmic strings, dark energy, dark matter, singularity, supernovae</td>
# </tr>
# <tr>
# 	<td>Interdisciplinary Branches</td>
# 	<td>Robotics, Plasma Physics, Astronomy (Astrodynamics, Astrometry, Astrobiology), Atmospheric Physics, Biophysics (Neurophysics, Quantum Biology), Chemical Physics/Physical Chemistry, Computational Physics, Geophysics, Materials Physics/Science, Mathematical Physics, Medical Physics, Ocean Physics/Physical Oceanography, Quantum Information Science, Philosophy of Physics, Psychophysics, Agrophysics, Space Physics, Econophysics, Environmental Physics, Engineering Physics, Quantum Computing, Sociophysics, Cryophysics/Cryogenics, Vehicle Dynamics</td>
# 	<td>Atmospheric pressure photoionization, Flotation of flexible objects, Mass versus weight, Asymptotic safety in quantum gravity, Covariant formulation of classical electromagnetism, Active and passive transformation, Causality, Quantum mind, Quantum brain dynamics</td>
# </tr>
# <tr>
# 	<td>Misc.</td>
# 	<td>Classical: Pressure physics, Chaos theory, Canonical quantization; Modern: Kinematic chain, Classical/Modern states, Plasma Physics, Transport Phenomena, Annihilation physics, Vacuum state physics, Stochastic process, Electroweak theory, Complex/Dynamical systems; Interdisciplinary: Combustion, Brownian motion, Observable universe, Multiverse, Emergence</td>
# 	<td>Ansatz, First principles, Coherent turbulent structure, Contracted Bianchi identities, Covariance group, Ergodic hypothesis, Euclidean vector, Gravitational contact terms, Hyperuniformity, Lorenz gauge condition, Mean-field theory, Negative frequency, Potentiometric surface, Quasistatic approximation, Relative locality, Relativistic heat conduction, Self-organization, Super Bloch oscillations, Sznajd model, Variable structure system, Free/Point/Virtual particles, Wigner–Weyl transform, Polynomial Wigner–Ville distribution, Wigner quasiprobability distribution, Maxwell–Boltzmann statistics, Bose–Einstein statistics, Vector potential, Vector space, State space, Phase space, Phase (matter), Phase space crystals</td>
# </tr>
#
# </table>
#
#
# __Notes__
# ---
# 1. "If, in some cataclysm, all of scientific knowledge were to be destroyed, and only one sentence passed on to the next generations ..., what statement would contain the most information in the fewest words? I believe it is [...] that _all things are made up of atoms – little particles that move around in perpetual motion, attracting each other when they are a little distance apart, but repelling upon being squeezed into one another. ..._" - Richard Feynman
# 4. "Physical science is that department of knowledge which relates to the order of nature, or, in other words, to the regular succession of events.", "Physical science is that department of knowledge which relates to the order of nature, or, in other words, to the regular succession of events." - J. C. Maxwell
# 5. "Physics is an _experimental_ science. Physicists observe the phenomena of nature and try to find patterns and principles that relate these phenomena. These patterns are called physical theories or, when they are very well established and of broad use, physical laws or principles." - Young & Freedman
#
# __References__
# ---
# 1. Feynman, R.P.; Leighton, R.B.; Sands, M. (1963). _The Feynman Lectures on Physics_. Vol. 1. ISBN 978-0-201-02116-5.
# 2. Maxwell, J.C. (1878). _Matter and Motion_. D. Van Nostrand. ISBN 978-0-486-66895-6. "matter and motion."
# 3. Perot, Pierre (1998). _A to Z of Thermodynamics_. Oxford University Press. ISBN 978-0-19-856552-9.
# 6. Van Ness, H.C. (1969). _Understanding Thermodynamics_. Dover Publications, Inc. ISBN 978-0-486-63277-3.
# 7. Dugdale, J. S. (1998). _Entropy and its Physical Meaning_. Taylor and Francis. ISBN 978-0-7484-0569-5.
# 8. Landau and Lifshitz (1951, 1962), _The Classical Theory of Fields_, Library of Congress Card Number 62-9181, Chapters 1–4 (3rd edition is ISBN 0-08-016019-0)
# 9. Edmund Taylor Whittaker (1904). _A Treatise on the Analytical Dynamics of Particles and Rigid Bodies_. Cambridge University Press. ISBN 978-0-521-35883-5.
# 10. Joseph Stiles Beggs (1983). _Kinematics_. Taylor & Francis. p. 1. ISBN 978-0-89116-355-8.
# 11. Thomas Wallace Wright (1896). _Elements of Mechanics Including Kinematics, Kinetics and Statics_. E and FN Spon. Chapter 1.
# 12. Corson and Lorrain, _Electromagnetic Fields and Waves_ ISBN 0-7167-1823-5
#
# __External Links__
# ---
# - AIP.org is the website of the American Institute of Physics
# - IOP.org is the website of the Institute of Physics
# - APS.org is the website of the American Physical Society
# - SPS National is the website of the American Society of Physics Students
# - CAP.ca is the website of the Canadian Association of Physicists
# - EPS.org is the website of the European Physical Society
# - Meta Institute for Computational Physics - Popular Talks
# - ScienceMathMastery - Compilation of YouTube Physics Courses
# - Physics | Channel | MIT Video
# - How to become a GOOD Theoretical Physicist, a website with outline of theoretical physics by Gerard 't Hooft
# - Resource recommendations - List of freely available physics books - Physics Stack Exchange
